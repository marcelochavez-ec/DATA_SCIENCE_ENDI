# %% [markdown]
# <h2 style="color: #004D7F; font-size: 36px; font-weight: bold;">Taller: Introducción a scikit-learn</h2>
#
# <h1 style="color: #004D7F; font-size: 30px;">Tópicos principales</h1>
#
# <br><br>
#
# <div style="text-align: left;">
#     <span style="color: #004D7F; font-size: 18px;">Marcelo Chávez</span><br>
#
# <a href="https://github.com/marcelochavez-ec/marcelochavez-ec" target="_blank">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/9/91/Octicons-mark-github.svg" alt="GitHub Logo" width="20px" style="margin-right: 10px;">
# </a>
# <a href="https://www.linkedin.com/in/marcelochavezec/" target="_blank">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/0/01/LinkedIn_Logo.svg" alt="LinkedIn Logo" width="60px">
# </a>
# </div>
#
# <div style="position: absolute; bottom: 10px; right: 10px;">
#     <a href="https://www.python.org/" target="_blank">
#         <img src="https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg" alt="Python Logo" width="50px">
#     </a>
# </div>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris
from funciones_main_graficos import *

# %%
# Instancio la función __def__ para llamarla con sus atributos o parámetos a llenar y graficar lo que el usuario necesita:

plot_iris_scatter(x_var=0,
                  y_var=1, 
                  title="Gráfico de Dispersión de Pétalos", 
                  subtitle="Comparación entre ancho y longitud del pétalo", 
                  footnote="Fuente: Datos Iris de sklearn")

# %%
# Scatter matrix
iris_df = pd.DataFrame(iris_data, columns=iris_dataset.feature_names)
pd.plotting.scatter_matrix(iris_df, c=iris_dataset.target)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Scatter matrix
# ----> 2 iris_df = pd.DataFrame(iris_data, columns=iris_dataset.feature_names)
#       3 pd.plotting.scatter_matrix(iris_df, c=iris_dataset.target)
#       5 plt.show()
#
# NameError: name 'iris_data' is not defined
