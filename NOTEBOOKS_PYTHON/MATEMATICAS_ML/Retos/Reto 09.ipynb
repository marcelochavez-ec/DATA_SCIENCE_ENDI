# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy.linalg as npl
from sympy import *

# %% [markdown]
# Realice las siguientes transformaciones lineales en una nube de puntos localizados dentro de un cuadrado.
# $$\textbf{A}_1=\begin{bmatrix}\cos(\frac{\pi}{4})&-\sin(\frac{\pi}{4})\\
# \sin(\frac{\pi}{4})& \cos(\frac{\pi}{4})\end{bmatrix}, \ \ \textbf{A}_2=\begin{bmatrix}2&0\\
# 0& 1\end{bmatrix}, \ \ \textbf{A}_3=\frac{1}{2}\begin{bmatrix}3&-1\\
# 1& -1\end{bmatrix}, \ \ $$

# %%
original = np.vstack([[i,j] for i in np.linspace(-1,1,20) for j in np.linspace(-1,1,20)])
scale = 5
plt.rcParams[ "figure.figsize" ] = (5,5)
plt.axis([-scale/2,scale/2,-scale/2,scale/2])
plt.scatter(original[:,0],original[:,1], c ='red')
plt.show()

# %%
# Se plantean las matrices de transformación
A1 = lambda theta: np.____([[np.cos(theta), -np.sin(theta)],
                              [np.sin(theta),np.cos(theta)]])
A2 = np.____([[2,0],
                [0,1]])
A3 = np.____([[3,-1],
                [1,-1]])*(1/2)
A1(np.pi/4)

# %%
print(original.shape)
# Hay que trasponer la matriz de datos orginales para que concuerden las dimensiones

# %%
# Se aplican las transformaciones
A1T = np.___(A1(np.pi/4),original.T).___  # Hay que trasponer nuevamente
A2T = np.___(A2,original.T).___
A3T = np.___(A3,original.T).__

# %%
# Graficar Transformacion A1
plt.axis([-scale/2,scale/2,-scale/2,scale/2])
plt.scatter(___[:,0],___[:,1], c ='blue')
plt.show()

# %%
# Graficar Transformacion A2
plt.axis([-scale/2,scale/2,-scale/2,scale/2])
plt.scatter(___[:,0],___[:,1], c ='green')
plt.show()

# %%
# Graficar Transformacion A3
plt.axis([-scale/2,scale/2,-scale/2,scale/2])
plt.scatter(___[:,0],___[:,1], c ='pink')
plt.show()
