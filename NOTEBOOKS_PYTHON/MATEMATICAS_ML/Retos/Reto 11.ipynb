# %%
import numpy as np
import numpy.linalg as npl
from sympy import *
import matplotlib.pyplot as plt

# %% [markdown]
# **Imagen y Kernel de un Mapeo Lineal**
#
# Obtenga la imagen y kernel del siguiente mapeo lineal
# $$\Phi:\mathbb{R}^4\rightarrow\mathbb{R}^2, \begin{bmatrix}x_1\\x_2\\x_3\\x_4\end{bmatrix}\mapsto\begin{bmatrix}1&2&-1&0\\
# 1&0&0&1\end{bmatrix}\begin{bmatrix}x_1\\x_2\\x_3\\x_4\end{bmatrix}=\begin{bmatrix}x_1+2x_2-x_3\\x_1+x_4\end{bmatrix}$$
# $$=x_1\begin{bmatrix}1\\1\end{bmatrix}+x_2\begin{bmatrix}2\\0\end{bmatrix}+x_3\begin{bmatrix}-1\\0\end{bmatrix}+x_4\begin{bmatrix}0\\1\end{bmatrix}$$
#
# Para determinar Im$(\Phi)$, podemos tomar el espacio generado de las columnas de la matriz de transformación y obtener
# $$\text{Im}(\Phi)=\text{span}\left[\begin{bmatrix}1\\1\end{bmatrix},\begin{bmatrix}2\\0\end{bmatrix},\begin{bmatrix}-1\\0\end{bmatrix},\begin{bmatrix}0\\1\end{bmatrix}\right].$$
#
# Para calcular el kernel (espacio nulo) de $\Phi$, se necesita resolver $\textbf{Ax=0}$, i.e., se necesita resolver el sistema homogéneo de ecuaciones. Para hacer esto, se usa eliminación Gaussiana para transformar $\textbf{A}$ en su forma escalonada reducida
# $$\begin{bmatrix}
# 1&2&-1&0\\1&0&0&1
# \end{bmatrix}\rightsquigarrow\begin{bmatrix}
# 1&0&0&1\\0&1&-\frac{1}{2}&-\frac{1}{2}
# \end{bmatrix}$$
#
# Utilizando el truco de -1 se obtiene fácilmente que
# $$\text{ker}(\Phi)=\text{span}\left\{\begin{bmatrix}0\\-\frac{1}{2}\\-1\\0\end{bmatrix},\begin{bmatrix}1\\-\frac{1}{2}\\0\\-1\end{bmatrix}\right\}$$

# %%
# Definimos el mapeo
Phi = ____([[1,2,-1,0],[1,0,0,1]])
print(Phi)
PhiRef = np.array(Phi.___()[0]).astype(np.float64)
Matrix(PhiRef)

# %%
# Calculamos el espacio generado de las columnas
image_PhiRef = npl.matrix_rank(____)
print(image_PhiRef)

# Truco de -1
PhiRef = np.____(PhiRef,2,np.array([0,0,-1,0]),0)
PhiRef = np.____(PhiRef,3,np.array([0,0,0,-1]),0)
PhiRef

# %%
# Calculamos la base
base_PhiRef = PhiRef[:,___:___]
base_PhiRef
