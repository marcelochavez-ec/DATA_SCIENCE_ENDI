# %% [markdown]
# # Carga de información a la base de datos BBDD_Hoteles
#
# En este documento realizamos la carga de los datos limpiados a la base de sql.

# %%
# Importamos las librerías necesarias
import pandas as pd
import numpy as np
import psycopg2 as ps
# Out:
# Running cells with 'endi' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n endi ipykernel --update-deps --force-reinstall'

# %%
# Importamos el csv con la información de las reservas, los hoteles y los clientes
data = pd.read_csv("../data/reservas_hoteles_limpio.csv", parse_dates=['fecha_reserva', 'inicio_estancia', 'final_estancia'], dtype={'id_cliente': str, 'id_hotel': str})
data.info()
# Out:
# Running cells with 'endi' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n endi ipykernel --update-deps --force-reinstall'

# %%
data[["id_hotel", "nombre_hotel"]]
# Out:
# Running cells with 'endi' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n endi ipykernel --update-deps --force-reinstall'

# %%
data["precio_noche"]
# Out:
# Running cells with 'endi' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n endi ipykernel --update-deps --force-reinstall'

# %%
# Importamos el csv con los eventos de Madrid sacados de la API
eventos = pd.read_csv("../data/eventos_madrid.csv", parse_dates=['fecha_inicio', 'fecha_fin'])
eventos.info()
# Out:
# Running cells with 'endi' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n endi ipykernel --update-deps --force-reinstall'

# %%
eventos[eventos["codigo_postal"] == 0]
# Out:
#                                          nombre_evento  \
# 2            Acompañamiento digital a personas mayores
# 12   Actividades mensuales de los centros de mayore...
# 15                                Apoyo a la autonomía
# 17           ArTrics - Laboratorio de Creación 2024/25
# 28                                 Ciclismo por Madrid
# 54                                   Correr por Madrid
# 99   Laboratorios ciudadanos: Rescatando la memoria...
# 115           Ludotecas en Centro Sociocultural Latina
# 123                               Meditación Vipassana
# 135  Puntos de intercambio gratuitos de libros en l...
# 144  Rutas Medioambientales Invierno 2025 - Distrit...
# 170             Taller Formativo de Producción Musical
#
#                                             url_evento  codigo_postal  \
# 2    http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 12   http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 15   http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 17   http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 28   http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 54   http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 99   http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 115  http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 123  http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 135  http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 144  http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
# 170  http://www.madrid.es/sites/v/index.jsp?vgnextc...              0
#
#     direccion horario                                       organizacion  \
# 2         NaN     NaN                                                NaN
# 12        NaN     NaN                                                NaN
# 15        NaN     NaN                                                NaN
# 17        NaN     NaN                                                NaN
# 28        NaN   00:00                                                NaN
# 54        NaN   00:00                                                NaN
# 99        NaN   10:00  Centro de Información y Educación Ambiental de...
# 115       NaN     NaN                                                NaN
# 123       NaN   09:45                                                NaN
# 135       NaN     NaN                                                NaN
# 144       NaN     NaN                                                NaN
# 170       NaN   16:30                                                NaN
#
#     fecha_inicio  fecha_fin
# 2     2024-10-14 2025-06-30
# 12    2024-02-01 2025-07-13
# 15    2024-09-13 2025-06-20
# 17    2024-10-01 2025-07-31
# 28    2024-09-01 2025-06-30
# 54    2024-09-01 2025-06-30
# 99    2025-02-01 2025-03-30
# 115   2024-10-05 2025-06-28
# 123   2024-09-18 2025-06-18
# 135   2023-04-10 2029-06-30
# 144   2025-01-19 2025-03-16
# 170   2025-02-10 2025-04-07

# %% [markdown]
# ## Inicialización de la conexión con la BBDD y el cursor

# %%
# Creamos la conexión a la base de datos
# Vamos a crear una conexión a la base de datos.
conn = ps.connect(
    dbname = "BBDD_Hoteles", # base a la que nos queremos conectar
    user = "postgres",
    password = "admin",
    host = "localhost",
    port = "5432" # puerto en el que s eencuentra postgres
)

# %%
# Creamos un cursor el cual nos va a permitir ejecutar querys.
cur = conn.cursor()

# %%
# COmprobamos que la conexión está creada y conectada
cur.execute("SELECT version();")
cur.fetchone()
# Out:
# ('PostgreSQL 16.4, compiled by Visual C++ build 1940, 64-bit',)

# %% [markdown]
# ## Inserción de datos

# %%
# COmprobamos que no haya valores duplicados en ambos dataframes
# data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Tabla ciudad

# %%
data_insert_ciudad = ["Madrid"]

# %%
# Creamos la query de inserción de los datos de ciudad
insert_query_ciudad = """ 
                        INSERT INTO ciudad (nombre_ciudad)
                        VALUES (%s) 
"""

# %%
# Ejecutamos la query y le indicamos que solo tenemos una ciudad que es Madrid
cur.execute(insert_query_ciudad, data_insert_ciudad)
conn.commit()

# %%
# vamos a comprobar que se ha creado correctamente
query_ciudad = """
    SELECT * 
    FROM ciudad; 
"""
cur.execute(query_ciudad)
cur.fetchall()
# Out:
# [(1, 'Madrid')]

# %% [markdown]
# # NO VOLVER A EJECUTAR LA QUERY DE CIUDAD, ESTA YA INSERTADA

# %% [markdown]
# ### Tabla eventos

# %%
conn.rollback()

# %%
# Sacamos el id de ciudad de la tabla de ciudad
cur.execute("SELECT nombre_ciudad, id_ciudad FROM ciudad")
dictio_ciudad = dict(cur.fetchall())
dictio_ciudad
# Out:
# {'Madrid': 1}

# %%
# Creamos la lista que va a contener toda la información 
data_insert_eventos = []

# Vamos iterando por cada columna del dataframe y cada fila de cada columna, obteniendo los elementos de las filas (row)
for i, row in eventos.iterrows():
    nombre_evento = row["nombre_evento"]
    url_evento = row["url_evento"]
    codigo_postal = row["codigo_postal"] if row["codigo_postal"] != 0 else None
    direccion = row["direccion"] if pd.notna(row["direccion"]) else None # tenemos valores nulos en esta columna, de manera que le indicamos, que si el elemento no es nulo nos lo coja, y si es nulo, nos incluya un None, ya que sql no acepta valores nulos que no sean None
    horario = row["horario"] if pd.notna(row["horario"]) else None
    fecha_inicio = row["fecha_inicio"]
    fecha_fin = row["fecha_fin"]
    organizacion = row["organizacion"] if pd.notna(row["organizacion"]) else None
    id_ciudad = dictio_ciudad.get("Madrid")

    # incluimos los valores en la lista
    data_insert_eventos.append((nombre_evento, url_evento, codigo_postal, direccion, horario, fecha_inicio, fecha_fin, organizacion, id_ciudad))

# %%
data_insert_eventos
# Out:
# [('60 Premio Reina Sofía de Pintura y Escultura',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=34c5130393e15910VgnVCM2000001f4a900aRCRD',
#   28009,
#   'PASEO COLOMBIA 1',
#   None,
#   Timestamp('2025-02-27 00:00:00'),
#   Timestamp('2025-03-23 00:00:00'),
#   'Centro Cultural Casa de Vacas (Retiro)',
#   1),
#  ('A toda vela',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=59d5e7da8b822910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2024-10-01 00:00:00'),
#   Timestamp('2025-06-01 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Acompañamiento digital a personas mayores',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=5b58d89ad2232910VgnVCM2000001f4a900aRCRD',
#   None,
#   None,
#   None,
#   Timestamp('2024-10-14 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   None,
#   1),
#  ('Acompañar en la pérdida',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=197023e4c84d3910VgnVCM2000001f4a900aRCRD',
#   28029,
#   'AVENIDA MONFORTE DE LEMOS 38',
#   '17:00',
#   Timestamp('2025-01-14 00:00:00'),
#   Timestamp('2025-06-17 00:00:00'),
#   'Biblioteca Pública Municipal José Saramago (Fuencarral-El Pardo)',
#   1),
#  ('Activas en compañía: gimnasia de mantenimiento',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f93102b68bf54910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '12:00',
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ("Actividades en el centro juvenil 'Carabanchel Alto'. Marzo 2025",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=c98efeefeb4fd810VgnVCM1000001d4a900aRCRD',
#   28044,
#   'CALLE ALFONSO FERNANDEZ 23',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Juvenil Carabanchel Alto',
#   1),
#  ("Actividades en el centro juvenil 'Chamberí'. Marzo 2025",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=296728f1aa80e810VgnVCM2000001f4a900aRCRD',
#   28003,
#   'CALLE RAIMUNDO FERNANDEZ VILLAVERDE 2',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Juvenil Chamberí',
#   1),
#  ("Actividades en el centro juvenil 'El Aleph' (Villa de Vallecas). Marzo 2025",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=185816ca7290e810VgnVCM2000001f4a900aRCRD',
#   28031,
#   'CALLE ZAZUAR 1',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Juvenil El Aleph (Villa de Vallecas)',
#   1),
#  ("Actividades en el centro juvenil 'El Sitio de mi recreo' (Villa de Vallecas). Marzo 2025",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=e90a16ca7290e810VgnVCM2000001f4a900aRCRD',
#   28031,
#   'CALLE REAL DE ARGANDA 39',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Juvenil El Sitio de mi Recreo (Villa de Vallecas)',
#   1),
#  ("Actividades en el centro juvenil 'Hontalbilla' (Fuencarral - El Pardo). Marzo 2025",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=c5d416ca7290e810VgnVCM2000001f4a900aRCRD',
#   28034,
#   'CALLE HONTALBILLA 10',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Juvenil Hontalbilla (Fuencarral - El Pardo)',
#   1),
#  ("Actividades en el centro juvenil 'Ouka Leele'. Marzo 2025.",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=51f73efea2652910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'CALLE BRONCE 16',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Juvenil Ouka Leele',
#   1),
#  ("Actividades en el centro juvenil 'Pipo Velasco'. Marzo 2025",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=8ff50712f95ed810VgnVCM2000001f4a900aRCRD',
#   28026,
#   'CALLE AVENA 5',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Juvenil Pipo Velasco (Usera)',
#   1),
#  ('Actividades mensuales de los centros de mayores del distrito Hortaleza',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=315479485bdeb810VgnVCM1000001d4a900aRCRD',
#   None,
#   None,
#   None,
#   Timestamp('2024-02-01 00:00:00'),
#   Timestamp('2025-07-13 00:00:00'),
#   None,
#   1),
#  ('Almudena Lobera. Secuencia Plano Secuencia',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=6f9e11c990735910VgnVCM1000001d4a900aRCRD',
#   28014,
#   'PLAZA CIBELES 1',
#   None,
#   Timestamp('2025-02-13 00:00:00'),
#   Timestamp('2025-06-08 00:00:00'),
#   'CentroCentro',
#   1),
#  ('Andrea Canepa «Wasi qaymi (Lugar y tacto)»',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=45f102a2fa0e1910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   None,
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-05-18 00:00:00'),
#   'Centro de Cultura Contemporánea Conde Duque',
#   1),
#  ('Apoyo a la autonomía',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1e67f7a45c701910VgnVCM1000001d4a900aRCRD',
#   None,
#   None,
#   None,
#   Timestamp('2024-09-13 00:00:00'),
#   Timestamp('2025-06-20 00:00:00'),
#   None,
#   1),
#  ('Artemisia. La magia de la luna',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=91dbd257d6d70910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'AVENIDA PLANETARIO 16',
#   '18:00',
#   Timestamp('2024-07-16 00:00:00'),
#   Timestamp('2025-12-28 00:00:00'),
#   'Planetario de Madrid',
#   1),
#  ('ArTrics - Laboratorio de Creación 2024/25',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=7ae9c00a26e12910VgnVCM1000001d4a900aRCRD',
#   None,
#   None,
#   None,
#   Timestamp('2024-10-01 00:00:00'),
#   Timestamp('2025-07-31 00:00:00'),
#   None,
#   1),
#  ('Asombro',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=85b965d37f624910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2025-01-18 00:00:00'),
#   Timestamp('2025-03-23 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Baile de Mayores en Centro Cultural Almirante Churruca',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=beaf2f9cb66d1610VgnVCM2000001f4a900aRCRD',
#   28024,
#   'CALLE FUENTE DEL TIRO 72',
#   '16:30',
#   Timestamp('2024-10-04 00:00:00'),
#   Timestamp('2025-06-27 00:00:00'),
#   'Centro Sociocultural Almirante Churruca (Latina)',
#   1),
#  ('Baile de Mayores en Centro Sociocultural El Greco',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=77922f9cb66d1610VgnVCM2000001f4a900aRCRD',
#   28011,
#   'CALLE EL GRECO 29',
#   '18:00',
#   Timestamp('2024-10-03 00:00:00'),
#   Timestamp('2025-06-26 00:00:00'),
#   'Centro Sociocultural El Greco (Latina)',
#   1),
#  ('Beethoven. Del corazón al corazón',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=3cd9168eeb173910VgnVCM1000001d4a900aRCRD',
#   28014,
#   'CALLE ALAMEDA 15',
#   None,
#   Timestamp('2024-12-03 00:00:00'),
#   Timestamp('2025-03-30 00:00:00'),
#   'Espacio Cultural Serrería Belga',
#   1),
#  ('Biblioajedrez',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=37340defdf5e1910VgnVCM2000001f4a900aRCRD',
#   28024,
#   'CALLE GRANJA DE TORREHERMOSA 1',
#   '18:00',
#   Timestamp('2024-09-30 00:00:00'),
#   Timestamp('2025-05-26 00:00:00'),
#   'Biblioteca Pública Municipal Ángel González (Latina)',
#   1),
#  ('Bodegones y Madrid',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=a903ec7bdcf54910VgnVCM1000001d4a900aRCRD',
#   28022,
#   'CALLE FEBRERO 4',
#   None,
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Cultural José Luis López Vázquez (San Blas - Canillejas)',
#   1),
#  ("By Lucipun ' Muladar creativo'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=32d3ef5066735910VgnVCM2000001f4a900aRCRD',
#   28001,
#   'CALLE NUÑEZ DE BALBOA 40',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-21 00:00:00'),
#   'Espacio Cultural Núñez de Balboa, 40 (Salamanca)',
#   1),
#  ('Caminamos juntas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=a54e02b68bf54910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '10:30',
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-03-25 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('Centro de Interpretación del Paisaje de la Luz',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=842dc5eb8e915810VgnVCM1000001d4a900aRCRD',
#   28014,
#   'PLAZA CIBELES 1',
#   None,
#   Timestamp('2022-12-14 00:00:00'),
#   Timestamp('2026-01-14 00:00:00'),
#   'CentroCentro',
#   1),
#  ('Chatines: club de lectura infantil',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=146e23279fad4910VgnVCM1000001d4a900aRCRD',
#   28036,
#   'CALLE MANUEL FERRERO 1',
#   '17:30',
#   Timestamp('2025-02-27 00:00:00'),
#   Timestamp('2025-06-19 00:00:00'),
#   'Biblioteca Pública Municipal Dámaso Alonso (Chamartín)',
#   1),
#  ('Ciclismo por Madrid',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=db40e3f0c91ea710VgnVCM2000001f4a900aRCRD',
#   None,
#   None,
#   '00:00',
#   Timestamp('2024-09-01 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   None,
#   1),
#  ('Cine familiar',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=d4fd2e979f0a0910VgnVCM2000001f4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2024-09-15 00:00:00'),
#   Timestamp('2025-06-29 00:00:00'),
#   'Cineteca Madrid',
#   1),
#  ('Círculo de ciudadanos',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=ba197bfae6da4910VgnVCM2000001f4a900aRCRD',
#   28029,
#   'AVENIDA MONFORTE DE LEMOS 38',
#   '17:00',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-12-16 00:00:00'),
#   'Biblioteca Pública Municipal José Saramago (Fuencarral-El Pardo)',
#   1),
#  ('Clara Torres Morenilla',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=d25a6e29da735910VgnVCM2000001f4a900aRCRD',
#   28028,
#   "CALLE ENRIQUE D'ALMONTE 1",
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-15 00:00:00'),
#   'Centro Cultural Quinta del Berro - Rafael Altamira (Salamanca)',
#   1),
#  ('Clases de árabe para niños',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=60ceedb3e8133910VgnVCM1000001d4a900aRCRD',
#   28041,
#   'AVENIDA SAN FERMIN 10',
#   '18:00',
#   Timestamp('2024-12-13 00:00:00'),
#   Timestamp('2025-05-30 00:00:00'),
#   'Biblioteca Pública Municipal San Fermín (Usera)',
#   1),
#  ('Club de lectura Biblioteca Vallecas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=a0fd177728c21910VgnVCM2000001f4a900aRCRD',
#   28053,
#   'CALLE PUERTO DEL MONASTERIO 1',
#   '10:00',
#   Timestamp('2024-09-27 00:00:00'),
#   Timestamp('2025-06-13 00:00:00'),
#   'Biblioteca Pública Municipal Vallecas (Puente de Vallecas)',
#   1),
#  ('Club de lectura de novela gráfica. Premios Nacionales de cómic',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f5210dae9a6da810VgnVCM2000001f4a900aRCRD',
#   28039,
#   'CALLE FRANCOS RODRIGUEZ 67',
#   '14:45',
#   Timestamp('2024-09-24 00:00:00'),
#   Timestamp('2025-05-27 00:00:00'),
#   'Biblioteca Pública Municipal Manuel Vázquez Montalbán (Tetuán)',
#   1),
#  ('Club de lectura en BPM María Zambrano',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f6dc84c649ef4910VgnVCM2000001f4a900aRCRD',
#   28029,
#   'PLAZA DONOSO 5',
#   '11:00',
#   Timestamp('2025-02-19 00:00:00'),
#   Timestamp('2025-06-25 00:00:00'),
#   'Biblioteca Pública Municipal María Zambrano (Tetuán)',
#   1),
#  ('Club de lectura en francés',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=0c129daebdc45910VgnVCM2000001f4a900aRCRD',
#   28041,
#   'PLAZA PUEBLO 2',
#   '17:00',
#   Timestamp('2025-02-17 00:00:00'),
#   Timestamp('2025-05-19 00:00:00'),
#   'Biblioteca Pública Municipal Gabriel García Márquez (Usera)',
#   1),
#  ("Club de lectura en inglés 'Reading Club'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=dc99b2481b1e1910VgnVCM2000001f4a900aRCRD',
#   28002,
#   'CALLE MANTUANO 51',
#   '19:00',
#   Timestamp('2024-10-08 00:00:00'),
#   Timestamp('2025-04-29 00:00:00'),
#   'Biblioteca Pública Municipal Francisco Ibáñez (Chamartín)',
#   1),
#  ("Club de lectura en inglés 'Reading Club'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=663cb2481b1e1910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'CALLE MARIA SEVILLA DIAGO 15',
#   '19:00',
#   Timestamp('2024-10-08 00:00:00'),
#   Timestamp('2025-04-29 00:00:00'),
#   'Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)',
#   1),
#  ("Club de lectura en inglés 'Reading Club'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=64c2b01c7d402910VgnVCM1000001d4a900aRCRD',
#   28005,
#   'CALLE SAN JUSTO 5',
#   '19:00',
#   Timestamp('2024-10-08 00:00:00'),
#   Timestamp('2025-04-29 00:00:00'),
#   'Biblioteca Pública Municipal Iván de Vargas (Centro)',
#   1),
#  ("Club de lectura en inglés 'Reading Club'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=4e37c32aae520910VgnVCM2000001f4a900aRCRD',
#   28004,
#   'CALLE BARCELO 4',
#   '19:00',
#   Timestamp('2024-10-07 00:00:00'),
#   Timestamp('2025-04-28 00:00:00'),
#   'Biblioteca Pública Municipal Mario Vargas Llosa (Centro)',
#   1),
#  ('Club de lectura Naomi Klein',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=342b3a03802e2910VgnVCM1000001d4a900aRCRD',
#   28005,
#   'CALLE SAN JUSTO 5',
#   '19:00',
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-05-28 00:00:00'),
#   'Biblioteca Pública Municipal Iván de Vargas (Centro)',
#   1),
#  ("Club de lectura 'Amigas de las letras'. Espacio de Igualdad Carme Chacón",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9da8470052eb2910VgnVCM2000001f4a900aRCRD',
#   28043,
#   'CALLE MATAPOZUELOS 2',
#   '17:00',
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-03-27 00:00:00'),
#   'Espacio de Igualdad Carme Chacón. Hortaleza',
#   1),
#  ("Club de lectura 'Veinte deseos'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=b75aa37147a02910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'CALLE MARIA SEVILLA DIAGO 15',
#   '19:00',
#   Timestamp('2024-10-02 00:00:00'),
#   Timestamp('2025-06-25 00:00:00'),
#   'Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)',
#   1),
#  ('Club de lectura (infantil) Biblioteca David Gistau',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=0c4bf9ea99e61910VgnVCM2000001f4a900aRCRD',
#   28028,
#   'AVENIDA TOREROS 5',
#   '18:00',
#   Timestamp('2024-09-30 00:00:00'),
#   Timestamp('2025-06-09 00:00:00'),
#   'Biblioteca Pública Municipal David Gistau (Salamanca)',
#   1),
#  ('Club de lectura (infantil) Biblioteca María Lejárraga',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=03cbf9ea99e61910VgnVCM2000001f4a900aRCRD',
#   28050,
#   'CALLE PRINCESA DE EBOLI 29',
#   '18:00',
#   Timestamp('2024-10-24 00:00:00'),
#   Timestamp('2025-06-19 00:00:00'),
#   'Biblioteca Pública Municipal María Lejárraga (Hortaleza)',
#   1),
#  ('Club de lectura (infantil) Biblioteca San Fermín',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=6304ee4e073b2910VgnVCM1000001d4a900aRCRD',
#   28041,
#   'AVENIDA SAN FERMIN 10',
#   '18:00',
#   Timestamp('2024-10-02 00:00:00'),
#   Timestamp('2025-06-18 00:00:00'),
#   'Biblioteca Pública Municipal San Fermín (Usera)',
#   1),
#  ('Club de lectura. Retiro',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=d5e34dbe8f624910VgnVCM2000001f4a900aRCRD',
#   28007,
#   'PLAZA DAOIZ Y VELARDE 2',
#   '18:00',
#   Timestamp('2025-01-16 00:00:00'),
#   Timestamp('2025-05-29 00:00:00'),
#   'Centro Sociocultural Clara Campoamor (Retiro)',
#   1),
#  ('Club de lectura: autoras africanas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=c278a6f664cb4910VgnVCM2000001f4a900aRCRD',
#   28007,
#   'CALLE ARREGUI Y ARUEJ 31',
#   '17:30',
#   Timestamp('2025-02-13 00:00:00'),
#   Timestamp('2025-03-27 00:00:00'),
#   'Espacio de Igualdad Elena Arnedo Soriano. Retiro',
#   1),
#  ("Club de lectura: 'Mujeres escritoras y lectoras'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9915b7a12d044910VgnVCM2000001f4a900aRCRD',
#   28039,
#   'CALLE ALMANSA 9',
#   '12:00',
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-03-25 00:00:00'),
#   'Centro Sociocultural José de Espronceda (Tetuán)',
#   1),
#  ('Coder Dojo · Grupo de trabajo 2024-2025',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=8c98b60f928d2910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PASEO CHOPERA 14',
#   None,
#   Timestamp('2024-11-16 00:00:00'),
#   Timestamp('2025-07-26 00:00:00'),
#   'Medialab Matadero',
#   1),
#  ('Colección de ilustraciones. Presente Continuo. Cosmo',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=98e33e8ae27a4910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PASEO CHOPERA 10',
#   None,
#   Timestamp('2025-02-24 00:00:00'),
#   Timestamp('2025-03-14 00:00:00'),
#   'Sala de exposiciones La Lonja. Centro Cultural Casa del Reloj (Arganzuela)',
#   1),
#  ('Conectores de la luz',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=fae4ebbe36624910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2025-01-18 00:00:00'),
#   Timestamp('2025-03-23 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Construimos herramientas para el empoderamiento',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=d48ab1ed8d964910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '18:15',
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-03-26 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('Correr por Madrid',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=712a8daaa32d4710VgnVCM1000001d4a900aRCRD',
#   None,
#   None,
#   '00:00',
#   Timestamp('2024-09-01 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   None,
#   1),
#  ('Curar las aguas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=589c4d742c535910VgnVCM2000001f4a900aRCRD',
#   28028,
#   'AVENIDA TOREROS 5',
#   None,
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-03-15 00:00:00'),
#   'Centro Cultural Buenavista (Salamanca)',
#   1),
#  ('Curso sobre la historia del Barrio del Pilar',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=c826b7021b7b1910VgnVCM2000001f4a900aRCRD',
#   28029,
#   'AVENIDA MONFORTE DE LEMOS 38',
#   '11:30',
#   Timestamp('2024-10-14 00:00:00'),
#   Timestamp('2025-04-28 00:00:00'),
#   'Biblioteca Pública Municipal José Saramago (Fuencarral-El Pardo)',
#   1),
#  ('Día de perros',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=90999daebdc45910VgnVCM2000001f4a900aRCRD',
#   28043,
#   'CALLE CARRIL DEL CONDE 57',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Cultural Carril del Conde (Hortaleza)',
#   1),
#  ('Educación pública',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=3b349c4490405910VgnVCM1000001d4a900aRCRD',
#   28029,
#   'PLAZA DONOSO 5',
#   None,
#   Timestamp('2025-02-17 00:00:00'),
#   Timestamp('2025-03-17 00:00:00'),
#   'Biblioteca Pública Municipal María Zambrano (Tetuán)',
#   1),
#  ('Ejercitando nuestro cuerpo',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=603002b68bf54910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '10:00',
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-03-26 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('El Bosque de los Recuerdos',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=4eea2ed891ad4910VgnVCM2000001f4a900aRCRD',
#   28029,
#   'PLAZA DONOSO 5',
#   '11:30',
#   Timestamp('2025-02-26 00:00:00'),
#   Timestamp('2025-07-23 00:00:00'),
#   'Biblioteca Pública Municipal María Zambrano (Tetuán)',
#   1),
#  ('El realismo en nuestra vida',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=3bcb9daebdc45910VgnVCM2000001f4a900aRCRD',
#   28033,
#   'CALLE SANTA VIRGILIA 15',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Cultural Hortaleza',
#   1),
#  ('Empoderamiento y relax',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=3713582a56f54910VgnVCM1000001d4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '10:00',
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-03-26 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('En calma. Taller de relajación',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=a2c6aed50c190910VgnVCM1000001d4a900aRCRD',
#   28043,
#   'CALLE MATAPOZUELOS 2',
#   '11:00',
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-04-28 00:00:00'),
#   'Espacio de Igualdad Carme Chacón. Hortaleza',
#   1),
#  ('En compañía de las letras',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=383d2a21725d3910VgnVCM1000001d4a900aRCRD',
#   28029,
#   'AVENIDA MONFORTE DE LEMOS 38',
#   '11:00',
#   Timestamp('2025-01-31 00:00:00'),
#   Timestamp('2025-06-27 00:00:00'),
#   'Biblioteca Pública Municipal José Saramago (Fuencarral-El Pardo)',
#   1),
#  ('Encyclopenglish',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=22533544ae1b4910VgnVCM2000001f4a900aRCRD',
#   28005,
#   'CALLE SAN JUSTO 5',
#   '19:00',
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-06-25 00:00:00'),
#   'Biblioteca Pública Municipal Iván de Vargas (Centro)',
#   1),
#  ('Entierro de la sardina. Se acabó la fiesta',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=134c7a0da9294910VgnVCM1000001d4a900aRCRD',
#   28001,
#   'CALLE GOYA 1',
#   None,
#   Timestamp('2025-02-21 00:00:00'),
#   Timestamp('2025-03-14 00:00:00'),
#   'Centro Cultural Emilia Pardo Bazán (Salamanca)',
#   1),
#  ('Entre pétalos y hojas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=95b99daebdc45910VgnVCM2000001f4a900aRCRD',
#   28043,
#   'CALLE CARRIL DEL CONDE 57',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Cultural Carril del Conde (Hortaleza)',
#   1),
#  ('Escritura creativa para mujeres: relatos y autorreflexión',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1b3823c4d617f810VgnVCM2000001f4a900aRCRD',
#   28007,
#   'CALLE ARREGUI Y ARUEJ 31',
#   '18:00',
#   Timestamp('2025-01-14 00:00:00'),
#   Timestamp('2025-06-24 00:00:00'),
#   'Espacio de Igualdad Elena Arnedo Soriano. Retiro',
#   1),
#  ('Escritura emocional. Espacio de Igualdad Carme Chacón',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=73b9470052eb2910VgnVCM2000001f4a900aRCRD',
#   28043,
#   'CALLE MATAPOZUELOS 2',
#   '11:00',
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-04-29 00:00:00'),
#   'Espacio de Igualdad Carme Chacón. Hortaleza',
#   1),
#  ('Escuela de espectadores sénior',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=06df85f1bda62910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PASEO CHOPERA 14',
#   None,
#   Timestamp('2024-10-03 00:00:00'),
#   Timestamp('2025-06-25 00:00:00'),
#   'Nave 10 Matadero. Creación Dramática Contemporánea',
#   1),
#  ('Escuela de Teatro. Teatro Municipal de Vallecas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=43c50a3c214f3810VgnVCM2000001f4a900aRCRD',
#   28031,
#   'CALLE PASO DE VILLAMANRIQUE 3',
#   None,
#   Timestamp('2024-09-01 00:00:00'),
#   Timestamp('2025-07-01 00:00:00'),
#   'Teatro Municipal de Vallecas',
#   1),
#  ('Espacio P.O.M 2024-25',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=663e02a2fa0e1910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   None,
#   Timestamp('2024-09-01 00:00:00'),
#   Timestamp('2025-05-31 00:00:00'),
#   'Centro de Cultura Contemporánea Conde Duque',
#   1),
#  ('Espacios naturales españoles, guardianes de la biodiversidad',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=fd4a29457e3e3910VgnVCM1000001d4a900aRCRD',
#   28009,
#   'PASEO FERNAN NUÑEZ 2',
#   '10:00',
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-03-30 00:00:00'),
#   'Centro de Información y Educación Ambiental de El Huerto de El Retiro',
#   1),
#  ('Estrenos Cineteca',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=0e63fc6a6f343910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2024-09-05 00:00:00'),
#   Timestamp('2025-07-31 00:00:00'),
#   'Cineteca Madrid',
#   1),
#  ('Explora y juega Matadero Madrid en Familia',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=d7fff2d5c9662910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2024-10-05 00:00:00'),
#   Timestamp('2026-06-30 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Exploradores de imágenes',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=13c5e7da8b822910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2024-10-01 00:00:00'),
#   Timestamp('2025-06-01 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Exposición de Pintura `Paisajes´ y `Rincones de Serradilla del Llano´',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=55bf157fd8e15910VgnVCM1000001d4a900aRCRD',
#   28021,
#   'ACCESO COLONIA MARCONI 4',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Sociocultural Marconi (Villaverde)',
#   1),
#  ('Exposición fotográfica: Fauna del entorno Meaques-Retamares',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=d2b072b8d63e3910VgnVCM2000001f4a900aRCRD',
#   28011,
#   'PARQUE CASA DE CAMPO (JUNTO AL EMBARCADERO DEL LAGO) ',
#   '10:00',
#   Timestamp('2025-01-02 00:00:00'),
#   Timestamp('2025-03-30 00:00:00'),
#   'Centro de Información y Educación Ambiental de Casa de Campo',
#   1),
#  ('Exposición: Giovanni Perluigi da Palestrina, compositor renacentista de música sacra',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=ba41e51b020e4910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   None,
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Biblioteca Musical Víctor Espinós',
#   1),
#  ('Fabricantes de historias',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f71667b761044910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2025-01-25 00:00:00'),
#   Timestamp('2025-03-15 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Falamos Português',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=48c4948aceca4910VgnVCM1000001d4a900aRCRD',
#   28029,
#   'AVENIDA MONFORTE DE LEMOS 38',
#   '18:00',
#   Timestamp('2025-02-21 00:00:00'),
#   Timestamp('2025-06-20 00:00:00'),
#   'Biblioteca Pública Municipal José Saramago (Fuencarral-El Pardo)',
#   1),
#  ('Fuentesal Arenillas e Itziar Okariz «CARRUSEL»',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9ec102a2fa0e1910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   None,
#   Timestamp('2025-02-27 00:00:00'),
#   Timestamp('2025-05-18 00:00:00'),
#   'Centro de Cultura Contemporánea Conde Duque',
#   1),
#  ('Ganchillo, punto o lo que queramos',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=fff5499d1fc63910VgnVCM1000001d4a900aRCRD',
#   28043,
#   'CALLE MATAPOZUELOS 2',
#   '11:00',
#   Timestamp('2025-01-07 00:00:00'),
#   Timestamp('2025-04-29 00:00:00'),
#   'Espacio de Igualdad Carme Chacón. Hortaleza',
#   1),
#  ('Grupo autónomo de Wikipedia',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=e4f04d15a5664910VgnVCM2000001f4a900aRCRD',
#   28039,
#   'CALLE BRAVO MURILLO 133',
#   '11:00',
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-03-27 00:00:00'),
#   'Espacio de Igualdad Hermanas Mirabal. Tetuán',
#   1),
#  ('Héctor Serrano',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=2b1fba93a70e4910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2025-02-27 00:00:00'),
#   Timestamp('2025-03-30 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Historia de una escalera',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=22bee2fc6e6c1910VgnVCM1000001d4a900aRCRD',
#   28012,
#   'CALLE PRINCIPE 25',
#   '19:00',
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-03-30 00:00:00'),
#   'Teatro Español',
#   1),
#  ('Informática nivel intermedio',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9f01d88f2de54910VgnVCM1000001d4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '10:30',
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('Iniciación a la informática',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9203d88f2de54910VgnVCM1000001d4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '10:30',
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('INVICTUS. El deporte madrileño a través de sus trofeos',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=880148eed77b4910VgnVCM2000001f4a900aRCRD',
#   28004,
#   'CALLE FUENCARRAL 78',
#   '10:00',
#   Timestamp('2025-01-30 00:00:00'),
#   Timestamp('2025-04-27 00:00:00'),
#   'Museo de Historia de Madrid',
#   1),
#  ('IV Edición del Certamen de Fotografía Villa de Vallecas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f3abcfac99225910VgnVCM2000001f4a900aRCRD',
#   28031,
#   'CALLE MANUEL VELEZ 10',
#   None,
#   Timestamp('2025-02-20 00:00:00'),
#   Timestamp('2025-03-21 00:00:00'),
#   'Centro Sociocultural Francisco Fatou (Villa de Vallecas)',
#   1),
#  ('IX Muestra de Orfebrería Contemporánea',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=33f41b63dd81b810VgnVCM1000001d4a900aRCRD',
#   28012,
#   'CALLE CONCEPCION JERONIMA 15',
#   '14:00',
#   Timestamp('2025-01-28 00:00:00'),
#   Timestamp('2025-03-23 00:00:00'),
#   'Imprenta Municipal - Artes del libro',
#   1),
#  ('IX Muestra Orfebrería Contemporánea',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9c329b6c617b4910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   '11:00',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-23 00:00:00'),
#   'Museo de Arte Contemporáneo de Madrid',
#   1),
#  ('Jornadas de filosofía. La mirada de la lechuza',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1705e01f5be02910VgnVCM2000001f4a900aRCRD',
#   28037,
#   'CALLE SAN ROMAN DEL VALLE 8',
#   None,
#   Timestamp('2024-10-03 00:00:00'),
#   Timestamp('2025-06-26 00:00:00'),
#   'Centro Cultural Antonio Machado (San Blas - Canillejas)',
#   1),
#  ('La Leyenda del Titanic',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=5ef58c83603a0910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2024-09-12 00:00:00'),
#   Timestamp('2025-07-31 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('La primavera en el mundo macro',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=4090157fd8e15910VgnVCM1000001d4a900aRCRD',
#   28004,
#   'CALLE BARCELO 4',
#   '08:30',
#   Timestamp('2025-02-21 00:00:00'),
#   Timestamp('2025-03-28 00:00:00'),
#   'Biblioteca Pública Municipal Mario Vargas Llosa (Centro)',
#   1),
#  ('La señorita de Trévelez',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=2f9fb0f8cebe1910VgnVCM1000001d4a900aRCRD',
#   28001,
#   'PLAZA COLON 4',
#   None,
#   Timestamp('2025-02-16 00:00:00'),
#   Timestamp('2025-04-20 00:00:00'),
#   'Fernán Gómez Centro Cultural de la Villa',
#   1),
#  ('La señorita de Trevélez:  Actividades',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=52af1c6aee645910VgnVCM1000001d4a900aRCRD',
#   28001,
#   'PLAZA COLON 4',
#   None,
#   Timestamp('2025-02-27 00:00:00'),
#   Timestamp('2025-04-20 00:00:00'),
#   'Fernán Gómez Centro Cultural de la Villa',
#   1),
#  ('Laboratorio de Técnicas de Estudio y Clases de Apoyo Escolar',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=912ed305de902910VgnVCM2000001f4a900aRCRD',
#   28021,
#   'ACCESO COLONIA MARCONI 4',
#   '18:00',
#   Timestamp('2024-10-07 00:00:00'),
#   Timestamp('2025-04-28 00:00:00'),
#   'Centro Sociocultural Marconi (Villaverde)',
#   1),
#  ('Laboratorios ciudadanos: Rescatando la memoria de la Dehesa de la Villa',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=0825a2fa9a3e3910VgnVCM1000001d4a900aRCRD',
#   None,
#   None,
#   '10:00',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-30 00:00:00'),
#   'Centro de Información y Educación Ambiental de Dehesa de la Villa',
#   1),
#  ('Las escénicas: taller de teatro para el empoderamiento femenino',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=434f02b68bf54910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '16:30',
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-03-26 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('Lectura de textos dramáticos traducidos, por Entre Bambalíneas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1ac9ec15205d3910VgnVCM2000001f4a900aRCRD',
#   28004,
#   'CALLE BARCELO 4',
#   '17:30',
#   Timestamp('2025-01-24 00:00:00'),
#   Timestamp('2025-06-20 00:00:00'),
#   'Biblioteca Pública Municipal Mario Vargas Llosa (Centro)',
#   1),
#  ('Libres y Seguras. Autodefensa feminista en el Espacio de Igualdad Lourdes Hernández',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=90fe82449be9e810VgnVCM1000001d4a900aRCRD',
#   28019,
#   'CALLE COMANDANTE FONTANES 8',
#   '18:00',
#   Timestamp('2025-01-23 00:00:00'),
#   Timestamp('2025-06-26 00:00:00'),
#   'Espacio de Igualdad Lourdes Hernández. Carabanchel',
#   1),
#  ('Literatura con nombre de mujer: Club de lectura.',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=07773d9181f54910VgnVCM1000001d4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '10:00',
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-03-28 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('Los malestares de Lucía, los malestares de todas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=82bfb1ed8d964910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '12:00',
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-03-27 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('Ludoteca',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=7b9d3a03802e2910VgnVCM1000001d4a900aRCRD',
#   28048,
#   'CALLE MIRA EL RIO 4',
#   '10:30',
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-29 00:00:00'),
#   'Centro Sociocultural Alfonso XII (Fuencarral - El Pardo)',
#   1),
#  ('Ludoteca en Centro Cultural  Miguel Hernández',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=424529ae67e9e810VgnVCM2000001f4a900aRCRD',
#   28044,
#   'CALLE SERRADILLA 13',
#   None,
#   Timestamp('2024-10-04 00:00:00'),
#   Timestamp('2025-06-28 00:00:00'),
#   'Centro Cultural Miguel Hernández (Latina)',
#   1),
#  ('Ludoteca en Centro Cultural Fernando de los Ríos',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=c62cdfaf0ae9e810VgnVCM2000001f4a900aRCRD',
#   28047,
#   'CALLE CAMARENA 10',
#   None,
#   Timestamp('2024-10-04 00:00:00'),
#   Timestamp('2025-06-28 00:00:00'),
#   'Centro Cultural Fernando de los Ríos (Latina)',
#   1),
#  ('Ludoteca en Centro Cultural José Luis Sampedro',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=88f129ae67e9e810VgnVCM2000001f4a900aRCRD',
#   28047,
#   'CALLE CASTROSERNA 4',
#   None,
#   Timestamp('2024-10-04 00:00:00'),
#   Timestamp('2025-06-28 00:00:00'),
#   'Centro Cultural José Luis Sampedro (Latina)',
#   1),
#  ('Ludoteca en Centro Cultural Sara Montiel',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=4f9000e8cdd9e810VgnVCM2000001f4a900aRCRD',
#   28024,
#   'CARRETERA BOADILLA DEL MONTE 40',
#   None,
#   Timestamp('2024-10-04 00:00:00'),
#   Timestamp('2025-06-28 00:00:00'),
#   'Centro Cultural Sara Montiel (Latina)',
#   1),
#  ('Ludoteca en Centro Sociocultural Almirante Churruca',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=eb0e29ae67e9e810VgnVCM2000001f4a900aRCRD',
#   28024,
#   'CALLE FUENTE DEL TIRO 72',
#   None,
#   Timestamp('2024-10-04 00:00:00'),
#   Timestamp('2025-06-28 00:00:00'),
#   'Centro Sociocultural Almirante Churruca (Latina)',
#   1),
#  ('Ludoteca en Centro Sociocultural El Greco',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=4a5029ae67e9e810VgnVCM2000001f4a900aRCRD',
#   28011,
#   'CALLE EL GRECO 29',
#   None,
#   Timestamp('2024-10-04 00:00:00'),
#   Timestamp('2025-06-28 00:00:00'),
#   'Centro Sociocultural El Greco (Latina)',
#   1),
#  ('Ludoteca en Centro Sociocultural Rosario Acuña',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=109ddfaf0ae9e810VgnVCM2000001f4a900aRCRD',
#   28011,
#   'CALLE MARIA DEL CARMEN 65',
#   None,
#   Timestamp('2024-10-05 00:00:00'),
#   Timestamp('2025-06-28 00:00:00'),
#   'Centro Sociocultural Rosario de Acuña (Latina)',
#   1),
#  ('Ludoteca en la Biblioteca Ángel González',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=50a99392d9f94810VgnVCM1000001d4a900aRCRD',
#   28024,
#   'CALLE GRANJA DE TORREHERMOSA 1',
#   '09:30',
#   Timestamp('2024-09-14 00:00:00'),
#   Timestamp('2025-05-31 00:00:00'),
#   'Biblioteca Pública Municipal Ángel González (Latina)',
#   1),
#  ('LUDOTECAS',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=007ec620e99d3910VgnVCM2000001f4a900aRCRD',
#   28034,
#   'PLAZA ISLAS AZORES 1',
#   '10:30',
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-29 00:00:00'),
#   'Centro Sociocultural Valverde (Fuencarral - El Pardo)',
#   1),
#  ('Ludotecas en Centro Sociocultural Latina',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=59c61197cb41f810VgnVCM1000001d4a900aRCRD',
#   None,
#   None,
#   None,
#   Timestamp('2024-10-05 00:00:00'),
#   Timestamp('2025-06-28 00:00:00'),
#   None,
#   1),
#  ('Ludotecas en el Centro Dotacional Integrado Arganzuela Ángel del Río',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1d2a63ea54ad4910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'CALLE CANARIAS 17',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-29 00:00:00'),
#   'Centro Dotacional Integrado Arganzuela Ángel del Río',
#   1),
#  ('Madrid Monumental: Antonio Palacios',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=d432e1f659714910VgnVCM2000001f4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 11',
#   '18:30',
#   Timestamp('2025-01-23 00:00:00'),
#   Timestamp('2025-12-31 00:00:00'),
#   'Hemeroteca Municipal',
#   1),
#  ('Madrid, Musa de las Letras',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=594444afb09f2910VgnVCM1000001d4a900aRCRD',
#   28014,
#   'CALLE ALAMEDA 15',
#   None,
#   Timestamp('2023-04-15 00:00:00'),
#   Timestamp('2025-12-31 00:00:00'),
#   'Espacio Cultural Serrería Belga',
#   1),
#  ('Madrileñas Ilustres: Rosario de Acuña (1850-1923)',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=a77f8f6c914d3910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   None,
#   Timestamp('2024-12-13 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   'Biblioteca Histórica Municipal',
#   1),
#  ('Martes de estiramientos',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=92b5811002304910VgnVCM1000001d4a900aRCRD',
#   28007,
#   'CALLE ARREGUI Y ARUEJ 31',
#   '10:00',
#   Timestamp('2025-01-14 00:00:00'),
#   Timestamp('2025-04-22 00:00:00'),
#   'Espacio de Igualdad Elena Arnedo Soriano. Retiro',
#   1),
#  ('Máscaras mágicas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=fe2e87330c444910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-04-05 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Me estiro y no me estreso',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=609a54036fb1d810VgnVCM1000001d4a900aRCRD',
#   28043,
#   'CALLE MATAPOZUELOS 2',
#   '18:00',
#   Timestamp('2025-01-08 00:00:00'),
#   Timestamp('2025-04-30 00:00:00'),
#   'Espacio de Igualdad Carme Chacón. Hortaleza',
#   1),
#  ('Meditación Vipassana',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=50231f760e2b1910VgnVCM2000001f4a900aRCRD',
#   None,
#   None,
#   '09:45',
#   Timestamp('2024-09-18 00:00:00'),
#   Timestamp('2025-06-18 00:00:00'),
#   None,
#   1),
#  ('Natacha',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=abeee2fc6e6c1910VgnVCM1000001d4a900aRCRD',
#   28012,
#   'CALLE PRINCIPE 25',
#   '19:30',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-30 00:00:00'),
#   'Teatro Español',
#   1),
#  ('Nerium Park',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=40029f45bf9e1910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PASEO CHOPERA 14',
#   '19:30',
#   Timestamp('2025-02-27 00:00:00'),
#   Timestamp('2025-03-23 00:00:00'),
#   'Nave 10 Matadero. Creación Dramática Contemporánea',
#   1),
#  ('Nuestros lugares en el barrio [Mujeres Compartiendo Sabiduría]',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=a3a1aff289ed2910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '10:30',
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-03-27 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('Orfebres en Madrid. IX Muestra de Orfebrería Contemporánea',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=2fdcb4e35c6b4910VgnVCM2000001f4a900aRCRD',
#   28004,
#   'CALLE FUENCARRAL 78',
#   '10:00',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-23 00:00:00'),
#   'Museo de Historia de Madrid',
#   1),
#  ('Panorama de los centros educativos de Tetuán',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=bdbad53414e15910VgnVCM1000001d4a900aRCRD',
#   28039,
#   'CALLE FRANCOS RODRIGUEZ 67',
#   None,
#   Timestamp('2025-02-19 00:00:00'),
#   Timestamp('2025-03-14 00:00:00'),
#   'Biblioteca Pública Municipal Manuel Vázquez Montalbán (Tetuán)',
#   1),
#  ('Parkour por Madrid',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=56b10f40cb9d0910VgnVCM2000001f4a900aRCRD',
#   28021,
#   'PASEO PLATA Y CASTAÑAR 7',
#   '00:00',
#   Timestamp('2024-09-01 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   'Centro Deportivo Municipal Plata y Castañar',
#   1),
#  ('Pasarela Brasil Fashion Madrid III Edición',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=e0a80089de4f4910VgnVCM2000001f4a900aRCRD',
#   28009,
#   'PASEO FERNÁN NÚÑEZ 24',
#   None,
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-16 00:00:00'),
#   'Biblioteca Pública Municipal Eugenio Trías. Casa de Fieras de El Retiro (Retiro)',
#   1),
#  ('Pintura realista con Acuarelables',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=8f2c93de293f3910VgnVCM2000001f4a900aRCRD',
#   28047,
#   'CALLE CASTROSERNA 4',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro Cultural José Luis Sampedro (Latina)',
#   1),
#  ('Piragüismo por Madrid',
# ...
#   Timestamp('2025-05-29 00:00:00'),
#   'Biblioteca Pública Municipal Gabriel García Márquez (Usera)',
#   1),
#  ('Taller de Poesía en la Biblioteca San Fermín',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=b4fc6e037df92910VgnVCM2000001f4a900aRCRD',
#   28041,
#   'AVENIDA SAN FERMIN 10',
#   '18:00',
#   Timestamp('2024-10-15 00:00:00'),
#   Timestamp('2025-06-17 00:00:00'),
#   'Biblioteca Pública Municipal San Fermín (Usera)',
#   1),
#  ('Taller de Poesía en la Biblioteca Vallecas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f0b09ab0b9c21910VgnVCM1000001d4a900aRCRD',
#   28053,
#   'CALLE PUERTO DEL MONASTERIO 1',
#   '10:00',
#   Timestamp('2024-10-01 00:00:00'),
#   Timestamp('2025-06-10 00:00:00'),
#   'Biblioteca Pública Municipal Vallecas (Puente de Vallecas)',
#   1),
#  ('Taller de Psicología en la Biblioteca Pozo del Tío Raimundo',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9b54e902e0631910VgnVCM1000001d4a900aRCRD',
#   28053,
#   'AVENIDA GLORIETAS 19',
#   '11:00',
#   Timestamp('2024-10-02 00:00:00'),
#   Timestamp('2025-05-28 00:00:00'),
#   'Biblioteca Pública Municipal Pozo del Tío Raimundo (Puente de Vallecas)',
#   1),
#  ('Taller de Psicología en la Biblioteca Vallecas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=2b0d6081f5f92910VgnVCM1000001d4a900aRCRD',
#   28053,
#   'CALLE PUERTO DEL MONASTERIO 1',
#   '10:00',
#   Timestamp('2024-10-18 00:00:00'),
#   Timestamp('2025-06-06 00:00:00'),
#   'Biblioteca Pública Municipal Vallecas (Puente de Vallecas)',
#   1),
#  ('Taller Formativo de Producción Musical',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=51133276cdfd4910VgnVCM1000001d4a900aRCRD',
#   None,
#   None,
#   '16:30',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-04-07 00:00:00'),
#   None,
#   1),
#  ("Taller 'Remedial English'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=5d86b2481b1e1910VgnVCM2000001f4a900aRCRD',
#   28022,
#   'CALLE MARIA SEVILLA DIAGO 15',
#   '18:00',
#   Timestamp('2024-10-08 00:00:00'),
#   Timestamp('2025-04-29 00:00:00'),
#   'Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)',
#   1),
#  ("Taller 'Remedial English'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9274b2481b1e1910VgnVCM2000001f4a900aRCRD',
#   28002,
#   'CALLE MANTUANO 51',
#   '18:00',
#   Timestamp('2024-10-08 00:00:00'),
#   Timestamp('2025-04-29 00:00:00'),
#   'Biblioteca Pública Municipal Francisco Ibáñez (Chamartín)',
#   1),
#  ("Taller 'Remedial English'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=cd6ab01c7d402910VgnVCM1000001d4a900aRCRD',
#   28005,
#   'CALLE SAN JUSTO 5',
#   '18:00',
#   Timestamp('2024-10-08 00:00:00'),
#   Timestamp('2025-04-29 00:00:00'),
#   'Biblioteca Pública Municipal Iván de Vargas (Centro)',
#   1),
#  ("Taller 'Remedial English'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=867b0525bf520910VgnVCM1000001d4a900aRCRD',
#   28004,
#   'CALLE BARCELO 4',
#   '18:00',
#   Timestamp('2024-10-07 00:00:00'),
#   Timestamp('2025-04-28 00:00:00'),
#   'Biblioteca Pública Municipal Mario Vargas Llosa (Centro)',
#   1),
#  ('Talleres creativos en idioma serbio',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=394cdaa14d721910VgnVCM2000001f4a900aRCRD',
#   28005,
#   'CALLE SAN JUSTO 5',
#   '11:00',
#   Timestamp('2024-09-22 00:00:00'),
#   Timestamp('2025-06-22 00:00:00'),
#   'Biblioteca Pública Municipal Iván de Vargas (Centro)',
#   1),
#  ('Talleres Familiares',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=5df152544dd2f810VgnVCM1000001d4a900aRCRD',
#   28049,
#   'Carretera M-607 Km 13 L-10 ',
#   '12:00',
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-29 00:00:00'),
#   'Centro de Interpretación de la Naturaleza Montecarmelo (Fuencarral - El Pardo)',
#   1),
#  ('Tecnologías tras las exposiciones inmersivas: sentir sin tocar',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=ab01d58d22984910VgnVCM1000001d4a900aRCRD',
#   28041,
#   'AVENIDA SAN FERMIN 10',
#   '18:00',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-06-06 00:00:00'),
#   'Biblioteca Pública Municipal San Fermín (Usera)',
#   1),
#  ('Tejedoras en autonomía [Mujeres Compartiendo Sabiduría]',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=c257582a56f54910VgnVCM1000001d4a900aRCRD',
#   28022,
#   'PLAZA EURIPIDES 1',
#   '17:00',
#   Timestamp('2025-01-09 00:00:00'),
#   Timestamp('2025-03-27 00:00:00'),
#   'Espacio de Igualdad Lucía Sánchez Saornil. San Blas-Canillejas',
#   1),
#  ('Tejiendo Colores',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f1868061b6e15910VgnVCM2000001f4a900aRCRD',
#   28026,
#   'CALLE DOCTOR TOLOSA LATOUR 16',
#   None,
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro de Educación Ambiental y Cultural Maris Stella (Usera)',
#   1),
#  ('Tejiendo palabras',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1d3bbc6b7dbc4910VgnVCM1000001d4a900aRCRD',
#   28025,
#   'CALLE GENERAL RICARDOS 252',
#   '11:00',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-05-20 00:00:00'),
#   'Biblioteca Pública Municipal La Chata (Carabanchel)',
#   1),
#  ('Tertulias de Filosofía en la Biblioteca Vallecas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=6626ce6dde131910VgnVCM1000001d4a900aRCRD',
#   28053,
#   'CALLE PUERTO DEL MONASTERIO 1',
#   '10:00',
#   Timestamp('2024-10-04 00:00:00'),
#   Timestamp('2025-05-30 00:00:00'),
#   'Biblioteca Pública Municipal Vallecas (Puente de Vallecas)',
#   1),
#  ('Tertulias de viajes: escucha, intercambia y comparte experiencias',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=3d7f28cb84672910VgnVCM2000001f4a900aRCRD',
#   28017,
#   'CALLE ASCAO 4',
#   '10:00',
#   Timestamp('2024-10-30 00:00:00'),
#   Timestamp('2025-05-21 00:00:00'),
#   'Biblioteca Pública Municipal Pablo Neruda (Ciudad Lineal)',
#   1),
#  ('Tertulias en francés en la Biblioteca Vargas Llosa',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f7fc27a924b41910VgnVCM2000001f4a900aRCRD',
#   28004,
#   'CALLE BARCELO 4',
#   '19:00',
#   Timestamp('2024-09-24 00:00:00'),
#   Timestamp('2025-06-10 00:00:00'),
#   'Biblioteca Pública Municipal Mario Vargas Llosa (Centro)',
#   1),
#  ('Tertulias en Inglés en la Biblioteca Gerardo Diego',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=73e6dc1e00af4910VgnVCM2000001f4a900aRCRD',
#   28031,
#   'CALLE MONTE AYA 12',
#   '19:00',
#   Timestamp('2025-01-13 00:00:00'),
#   Timestamp('2025-05-26 00:00:00'),
#   'Biblioteca Pública Municipal Gerardo Diego (Villa de Vallecas)',
#   1),
#  ('Tertulias en Inglés en la Biblioteca Miguel Delibes',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=ed0f5ab3b2f64910VgnVCM1000001d4a900aRCRD',
#   28030,
#   'CALLE ARROYO BELINCOSO 11',
#   '18:30',
#   Timestamp('2025-01-17 00:00:00'),
#   Timestamp('2025-05-30 00:00:00'),
#   'Biblioteca Pública Municipal Miguel Delibes (Moratalaz)',
#   1),
#  ('Tertulias en Inglés en la Biblioteca Portazgo',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=ae6016630a815910VgnVCM2000001f4a900aRCRD',
#   28038,
#   'CALLE CANTALAPIEDRA 11',
#   '11:00',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-06-17 00:00:00'),
#   'Biblioteca Pública Municipal Portazgo (Puente de Vallecas)',
#   1),
#  ('Tertulias en Inglés en la Biblioteca San Fermín',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1ad33527bea41910VgnVCM1000001d4a900aRCRD',
#   28041,
#   'AVENIDA SAN FERMIN 10',
#   '19:00',
#   Timestamp('2024-10-02 00:00:00'),
#   Timestamp('2025-06-18 00:00:00'),
#   'Biblioteca Pública Municipal San Fermín (Usera)',
#   1),
#  ('Tertulias en Inglés (infantil) Biblioteca Vallecas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=eec46c112bc41910VgnVCM2000001f4a900aRCRD',
#   28053,
#   'CALLE PUERTO DEL MONASTERIO 1',
#   '18:00',
#   Timestamp('2024-09-25 00:00:00'),
#   Timestamp('2025-06-11 00:00:00'),
#   'Biblioteca Pública Municipal Vallecas (Puente de Vallecas)',
#   1),
#  ('Top Secret: aventuras, sueños y mentiras',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9afd87330c444910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2025-01-26 00:00:00'),
#   Timestamp('2025-03-16 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Triatlón por Madrid',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=4e703104e46fa710VgnVCM1000001d4a900aRCRD',
#   28011,
#   'PASEO PUERTA DEL ANGEL 7',
#   '00:00',
#   Timestamp('2024-09-01 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   'Centro Deportivo Municipal Casa de Campo',
#   1),
#  ('Triatlón por Madrid',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=86742bbbbdc89810VgnVCM2000001f4a900aRCRD',
#   28042,
#   'AVENIDA LOGROÑO 70',
#   '00:00',
#   Timestamp('2024-09-01 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   'Centro Deportivo Municipal Barajas',
#   1),
#  ('Triatlón por Madrid',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f7df3104e46fa710VgnVCM1000001d4a900aRCRD',
#   28031,
#   'CALLE CERRO DE ALMODOVAR 9',
#   '00:00',
#   Timestamp('2024-09-01 00:00:00'),
#   Timestamp('2025-06-30 00:00:00'),
#   'Centro Deportivo Municipal Cerro Almodóvar',
#   1),
#  ('Trópico sin tópico: Amazonas',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=517b08502f864910VgnVCM1000001d4a900aRCRD',
#   28014,
#   'PLAZA CIBELES 1',
#   None,
#   Timestamp('2025-02-13 00:00:00'),
#   Timestamp('2025-06-22 00:00:00'),
#   'CentroCentro',
#   1),
#  ('Tú, yo y el mundo. La Colmena',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=7f6402a2fa0e1910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   None,
#   Timestamp('2024-10-08 00:00:00'),
#   Timestamp('2025-05-27 00:00:00'),
#   'Centro de Cultura Contemporánea Conde Duque',
#   1),
#  ('Una mirada a través del tiempo',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=b2c423122abc4910VgnVCM1000001d4a900aRCRD',
#   28022,
#   'CALLE MARIA SEVILLA DIAGO 15',
#   None,
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-28 00:00:00'),
#   'Biblioteca Pública Municipal José Hierro (San Blas-Canillejas)',
#   1),
#  ('Vida',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f2edddd487835910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   '08:30',
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Biblioteca Pública Municipal Benito Pérez Galdós (Centro)',
#   1),
#  ('Vida del Palacio de Cibeles',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=df2b06e5faa72910VgnVCM1000001d4a900aRCRD',
#   28014,
#   'PLAZA CIBELES 1',
#   None,
#   Timestamp('2024-10-11 00:00:00'),
#   Timestamp('2025-10-13 00:00:00'),
#   'CentroCentro',
#   1),
#  ("Visita a la exposición permanente Maris Stella, un sueño de todos'",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=f745ce5179e61910VgnVCM1000001d4a900aRCRD',
#   28026,
#   'CALLE DOCTOR TOLOSA LATOUR 16',
#   None,
#   Timestamp('2024-08-20 00:00:00'),
#   Timestamp('2025-03-31 00:00:00'),
#   'Centro de Educación Ambiental y Cultural Maris Stella (Usera)',
#   1),
#  ('Visitas a Matadero',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=0d3cc39a88fb5810VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2024-09-09 00:00:00'),
#   Timestamp('2025-07-07 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Visitas a Matadero para grupos',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=7aee08f9be116810VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   Timestamp('2023-02-02 00:00:00'),
#   Timestamp('2027-02-04 00:00:00'),
#   'Matadero Madrid',
#   1),
#  ('Visitas dialogadas. Fuentesal Arenillas e Itziar Okariz «CARRUSEL»',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=9b3fba93a70e4910VgnVCM1000001d4a900aRCRD',
#   28015,
#   'CALLE CONDE DUQUE 9',
#   None,
#   Timestamp('2025-02-28 00:00:00'),
#   Timestamp('2025-05-18 00:00:00'),
#   'Centro de Cultura Contemporánea Conde Duque',
#   1),
#  ('Visitas guiadas a CentroCentro',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=a9dbd981f4ab5810VgnVCM1000001d4a900aRCRD',
#   28014,
#   'PLAZA CIBELES 1',
#   None,
#   Timestamp('2024-04-01 00:00:00'),
#   Timestamp('2030-01-01 00:00:00'),
#   'CentroCentro',
#   1),
#  ('Visitas guiadas a las exposiciones de CentroCentro',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=da941a577f8f4910VgnVCM1000001d4a900aRCRD',
#   28014,
#   'PLAZA CIBELES 1',
#   None,
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-06-01 00:00:00'),
#   'CentroCentro',
#   1),
#  ('Wikiesfera &gt; Aprendiendo a editar en Wikipedia',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=28be106762794910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PASEO CHOPERA 14',
#   '18:00',
#   Timestamp('2025-01-29 00:00:00'),
#   Timestamp('2025-03-27 00:00:00'),
#   'Medialab Matadero',
#   1),
#  ('Y tú, ¿cómo viajas?',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=1647417016603910VgnVCM1000001d4a900aRCRD',
#   28037,
#   'CALLE HERMANOS GARCIA NOBLEJAS 14',
#   '10:00',
#   Timestamp('2024-12-04 00:00:00'),
#   Timestamp('2025-05-28 00:00:00'),
#   'Biblioteca Pública Municipal Ciudad Lineal (Ciudad Lineal)',
#   1),
#  ("'Lina en el mundo de Paul Klee' por Alejandra Bonmatí Arnau",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=e478ce5f1ccc4910VgnVCM2000001f4a900aRCRD',
#   28029,
#   'AVENIDA MONFORTE DE LEMOS 38',
#   '08:30',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-25 00:00:00'),
#   'Biblioteca Pública Municipal José Saramago (Fuencarral-El Pardo)',
#   1),
#  ("'Refugiados' por Myriam Laguía",
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=239617d42cad4910VgnVCM1000001d4a900aRCRD',
#   28019,
#   'CALLE ISAAC ALBENIZ 1',
#   '19:00',
#   Timestamp('2025-02-14 00:00:00'),
#   Timestamp('2025-03-13 00:00:00'),
#   'Biblioteca Pública Municipal Ana María Matute (Carabanchel)',
#   1),
#  ('¡Ahora nos toca jugar! Juegos de mesa',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=536b470052eb2910VgnVCM2000001f4a900aRCRD',
#   28043,
#   'CALLE MATAPOZUELOS 2',
#   '11:00',
#   Timestamp('2025-01-03 00:00:00'),
#   Timestamp('2025-03-28 00:00:00'),
#   'Espacio de Igualdad Carme Chacón. Hortaleza',
#   1)]

# %%
# Creamos la query de inserción de los datos de eventos
insert_query_eventos = """ 
                        INSERT INTO eventos (nombre_evento, url_evento, codigo_postal, direccion, horario,
                        fecha_inicio, fecha_fin,organizacion, id_ciudad)
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
# Ejecutamos la query y le indicamos los valores 
cur.executemany(insert_query_eventos, data_insert_eventos)
conn.commit()

# %%
# vamos a comprobar que se ha creado correctamente
query_eventos = """
    SELECT * 
    FROM eventos; 
"""
cur.execute(query_eventos)
cur.fetchmany(3)
# Out:
# [(1,
#   '60 Premio Reina Sofía de Pintura y Escultura',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=34c5130393e15910VgnVCM2000001f4a900aRCRD',
#   28009,
#   'PASEO COLOMBIA 1',
#   None,
#   datetime.date(2025, 2, 27),
#   datetime.date(2025, 3, 23),
#   'Centro Cultural Casa de Vacas (Retiro)',
#   1),
#  (2,
#   'A toda vela',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=59d5e7da8b822910VgnVCM1000001d4a900aRCRD',
#   28045,
#   'PLAZA LEGAZPI 8',
#   None,
#   datetime.date(2024, 10, 1),
#   datetime.date(2025, 6, 1),
#   'Matadero Madrid',
#   1),
#  (3,
#   'Acompañamiento digital a personas mayores',
#   'http://www.madrid.es/sites/v/index.jsp?vgnextchannel=ca9671ee4a9eb410VgnVCM100000171f5a0aRCRD&vgnextoid=5b58d89ad2232910VgnVCM2000001f4a900aRCRD',
#   None,
#   None,
#   None,
#   datetime.date(2024, 10, 14),
#   datetime.date(2025, 6, 30),
#   None,
#   1)]

# %% [markdown]
# # NO VOLVER A EJECUTAR LA QUERY DE EVENTOS, ESTA YA INSERTADA

# %% [markdown]
# ### Tabla hoteles

# %%
# revisar tipo de datos
data.columns
# Out:
# Index(['id_reserva', 'id_cliente', 'nombre', 'apellido', 'mail', 'competencia',
#        'fecha_reserva', 'inicio_estancia', 'final_estancia', 'id_hotel',
#        'nombre_hotel', 'ciudad', 'precio_noche', 'estrellas'],
#       dtype='object')

# %%
data_insert_hotels = []

for _, row in data.iterrows():
    id_hotel = row["id_hotel"]
    nombre_hotel = row["nombre_hotel"] 
    competencia = row["competencia"] 
    valoracion = row["estrellas"] 
    id_ciudad = dictio_ciudad.get("Madrid") 

    tupla_hotel = (id_hotel, nombre_hotel, competencia, valoracion, id_ciudad)

    if tupla_hotel not in data_insert_hotels:
        data_insert_hotels.append(tupla_hotel)

# %%
data_insert_hotels
# Out:
# [('1', 'Hotel Monte Verde', False, 3.1, 1),
#  ('2', 'Hotel Brisas del Mar', False, 3.09, 1),
#  ('3', 'Hotel Camino del Sol', False, 3.07, 1),
#  ('4', 'Hotel Puerta del Cielo', False, 3.03, 1),
#  ('5', 'Hotel Encanto Real', False, 3.03, 1),
#  ('6', 'Palacio del Sol', False, 2.99, 1),
#  ('7', 'Hotel Jardines del Rey', False, 2.94, 1),
#  ('8', 'Hotel Las Estrellas', False, 2.91, 1),
#  ('9', 'Gran Hotel Madrid', False, 3.07, 1),
#  ('10', 'Hotel Torre Dorada', False, 2.92, 1),
#  ('11', 'Hotel Palacio Imperial', False, 3.01, 1),
#  ('12', 'Hotel Luz de Madrid', False, 3.05, 1),
#  ('13', 'Hotel Los Almendros', False, 3.01, 1),
#  ('14', 'Hotel Sol y Luna', False, 3.01, 1),
#  ('15', 'Hotel Mirador Real', False, 2.98, 1),
#  ('16', 'Hotel Rincón Sereno', False, 3.0, 1),
#  ('17', 'Hotel Vista Alegre', False, 2.94, 1),
#  ('18', 'Hotel Costa Azul', False, 3.12, 1),
#  ('19', 'Hotel Maravilla Real', False, 2.98, 1),
#  ('20', 'ibis Styles Madrid Prado', True, 4.7, 1),
#  ('21', 'ibis Styles Madrid Centro Maravillas', True, 4.7, 1),
#  ('22', 'ibis Madrid Centro las Ventas', True, 4.5, 1),
#  ('23', 'ibis budget Madrid Centro las Ventas', True, 4.3, 1),
#  ('24', 'ibis Styles Madrid City Las Ventas', True, 4.6, 1),
#  ('25', 'ibis budget Madrid Calle Alcalá', True, 4.3, 1),
#  ('26', 'ibis Madrid Calle Alcalá', True, 4.5, 1),
#  ('27', 'ibis budget Madrid Vallecas', True, 4.3, 1),
#  ('28', 'ibis Madrid Getafe', True, 4.4, 1),
#  ('29', 'ibis Madrid Aeropuerto Barajas', True, 4.4, 1)]

# %%
# Creamos la query de inserción de los datos de ciudad
insert_query_hoteles = """ 
                        INSERT INTO hoteles (id_hotel, nombre_hotel, competencia, valoracion, id_ciudad)
                        VALUES (%s, %s, %s, %s, %s)
"""

# %%
# Ejecutamos la query y le indicamos los valores 
cur.executemany(insert_query_hoteles, data_insert_hotels)
conn.commit()

# %%
# vamos a comprobar que se ha creado correctamente
query_hoteles = """
    SELECT * 
    FROM hoteles; 
"""
cur.execute(query_hoteles)
cur.fetchmany(3)
# Out:
# [('1', 'Hotel Monte Verde', False, 3.1, 1),
#  ('2', 'Hotel Brisas del Mar', False, 3.09, 1),
#  ('3', 'Hotel Camino del Sol', False, 3.07, 1)]

# %% [markdown]
# # HOTELES ESTA PERFECTO NO TOCAR MAS

# %% [markdown]
# ### Tabla clientes

# %%
# revisar tipo de datos
data.columns
# Out:
# Index(['id_reserva', 'id_cliente', 'nombre', 'apellido', 'mail', 'competencia',
#        'fecha_reserva', 'inicio_estancia', 'final_estancia', 'id_hotel',
#        'nombre_hotel', 'ciudad', 'precio_noche', 'estrellas'],
#       dtype='object')

# %%
data_insert_clientes = []

for _, row in data.iterrows():

    id_cliente = row["id_cliente"]
    nombre = row["nombre"],
    apellido = row["apellido"],
    mail = row["mail"]

    tupla_cliente = (id_cliente, nombre, apellido, mail)

    if tupla_cliente not in data_insert_clientes:
        data_insert_clientes.append(tupla_cliente)

# %%
# Creamos la query de inserción de los datos de ciudad
insert_query_clientes = """ 
                        INSERT INTO clientes (id_cliente, nombre, apellido, mail)
                        VALUES (%s, %s, %s, %s)
"""

# %%
# Ejecutamos la query y le indicamos los valores 
cur.executemany(insert_query_clientes, data_insert_clientes)
conn.commit()

# %%
# vamos a comprobar que se ha creado correctamente
query_clientes = """
    SELECT * 
    FROM clientes; 
"""
cur.execute(query_clientes)
cur.fetchmany(3)
# Out:
# [('1', 'Maite', 'Calatayud', 'maite.calatayud@example.com'),
#  ('2', 'Tecla', 'Bonet', 'tecla.bonet@example.com'),
#  ('3', 'Amílcar', 'Andrés', 'amílcar.andrés@example.com')]

# %% [markdown]
# ### Tabla reservas

# %%
# revisar tipo de datos
data.columns
# Out:
# Index(['id_reserva', 'id_cliente', 'nombre', 'apellido', 'mail', 'competencia',
#        'fecha_reserva', 'inicio_estancia', 'final_estancia', 'id_hotel',
#        'nombre_hotel', 'ciudad', 'precio_noche', 'estrellas'],
#       dtype='object')

# %%
# Sacamos el id de clientes de la tabla de clientes
cur.execute("SELECT mail, id_cliente FROM clientes")
dictio_clientes = dict(cur.fetchall())
dictio_clientes
# Out:
# {'maite.calatayud@example.com': '1',
#  'tecla.bonet@example.com': '2',
#  'amílcar.andrés@example.com': '3',
#  'joan.vazquez@example.com': '4',
#  'chelo.flor@example.com': '5',
#  'dolores.lobo@example.com': '6',
#  'noé.lobo@example.com': '7',
#  'omar.lamas@example.com': '8',
#  'ágata.pinedo@example.com': '9',
#  'julie.baños@example.com': '10',
#  'javier.mancebo@example.com': '11',
#  'rita.guerrero@example.com': '12',
#  'ricardo.lobo@example.com': '13',
#  'perlita.patiño@example.com': '14',
#  'pedro.gallego@example.com': '15',
#  'judith.bellido@example.com': '16',
#  'francisco javier.hierro@example.com': '17',
#  'reynaldo.lerma@example.com': '18',
#  'felicidad.gimenez@example.com': '19',
#  'pía.barba@example.com': '20',
#  'amílcar.moles@example.com': '21',
#  'blas.galván@example.com': '22',
#  'claudia.miranda@example.com': '23',
#  'fernanda.segarra@example.com': '24',
#  'emilio.huerta@example.com': '25',
#  'bárbara.jódar@example.com': '26',
#  'emiliano.vergara@example.com': '27',
#  'marisol.arévalo@example.com': '28',
#  'ezequiel.cuesta@example.com': '29',
#  'telmo.bartolomé@example.com': '30',
#  'débora.solé@example.com': '31',
#  'darío.lasa@example.com': '32',
#  'fausto.santiago@example.com': '33',
#  'lorenza.lago@example.com': '34',
#  'anunciación.flor@example.com': '35',
#  'maría belén.cuéllar@example.com': '36',
#  'amaya.aliaga@example.com': '37',
#  'jose angel.bermúdez@example.com': '38',
#  'berta.casas@example.com': '39',
#  'salud.rocha@example.com': '40',
#  'úrsula.font@example.com': '41',
#  'sabas.perea@example.com': '42',
#  'asunción.sanmiguel@example.com': '43',
#  'jafet.baró@example.com': '44',
#  'adrián.belda@example.com': '45',
#  'benigno.granados@example.com': '46',
#  'amílcar.murillo@example.com': '47',
#  'jordán.lopez@example.com': '48',
#  'sofía.suárez@example.com': '49',
#  'ainara.ramírez@example.com': '50',
#  'segismundo.solera@example.com': '51',
#  'luisa.nicolau@example.com': '52',
#  'césar.ibarra@example.com': '53',
#  'brunilda.sanabria@example.com': '54',
#  'gervasio.lopez@example.com': '55',
#  'sandra.benet@example.com': '56',
#  'calixta.alcolea@example.com': '57',
#  'ángeles.guzmán@example.com': '58',
#  'salvador.barral@example.com': '59',
#  'abilio.portero@example.com': '60',
#  'josefina.torrecilla@example.com': '61',
#  'manu.gelabert@example.com': '62',
#  'cruz.barrera@example.com': '63',
#  'joel.quintanilla@example.com': '64',
#  'aníbal.bilbao@example.com': '65',
#  'juan carlos.fuente@example.com': '66',
#  'ignacio.velasco@example.com': '67',
#  'paco.bayona@example.com': '68',
#  'rafael.lópez@example.com': '69',
#  'perla.mate@example.com': '70',
#  'olga.marí@example.com': '71',
#  'cristóbal.cañizares@example.com': '72',
#  'humberto.novoa@example.com': '73',
#  'fabiana.laguna@example.com': '74',
#  'teo.lloret@example.com': '75',
#  'nazario.castrillo@example.com': '76',
#  'juan francisco.cuéllar@example.com': '77',
#  'jessica.company@example.com': '78',
#  'eusebio.ropero@example.com': '79',
#  'mario.pastor@example.com': '80',
#  'paulino.ramos@example.com': '81',
#  'jordi.cámara@example.com': '82',
#  'amador.escobar@example.com': '83',
#  'nazaret.requena@example.com': '84',
#  'otilia.goñi@example.com': '85',
#  'georgina.ferrando@example.com': '86',
#  'león.baños@example.com': '87',
#  'león.ortega@example.com': '88',
#  'salomón.muñoz@example.com': '89',
#  'david.julián@example.com': '90',
#  'corona.falcón@example.com': '91',
#  'marcelo.vendrell@example.com': '92',
#  'sebastian.morera@example.com': '93',
#  'manolo.castejón@example.com': '94',
#  'graciana.pinilla@example.com': '95',
#  'vanesa.dávila@example.com': '96',
#  'marcial.ramis@example.com': '97',
#  'aarón.mateu@example.com': '98',
#  'tito.montserrat@example.com': '99',
#  'vasco.garcía@example.com': '100',
#  'nadia.doménech@example.com': '101',
#  'loreto.villalba@example.com': '102',
#  'estefanía.naranjo@example.com': '103',
#  'arturo.hierro@example.com': '104',
#  'emiliana.beltran@example.com': '105',
#  'rodrigo.urrutia@example.com': '106',
#  'isidoro.echeverría@example.com': '107',
#  'josefa.villaverde@example.com': '108',
#  'cecilia.ibañez@example.com': '109',
#  'victoria.salmerón@example.com': '110',
#  'mar.taboada@example.com': '111',
#  'maricruz.huertas@example.com': '112',
#  'leonel.vázquez@example.com': '113',
#  'jorge.llobet@example.com': '114',
#  'nico.montenegro@example.com': '115',
#  'cecilio.chacón@example.com': '116',
#  'rodolfo.corominas@example.com': '117',
#  'bernardo.ribera@example.com': '118',
#  'candela.solano@example.com': '119',
#  'maría luisa.aller@example.com': '120',
#  'reyna.rius@example.com': '121',
#  'leandro.ruano@example.com': '122',
#  'roque.navarrete@example.com': '123',
#  'nazaret.quiroga@example.com': '124',
#  'priscila.solsona@example.com': '125',
#  'esther.amores@example.com': '126',
#  'dora.amores@example.com': '127',
#  'tiburcio.cerdá@example.com': '128',
#  'germán.ayllón@example.com': '129',
#  'nicolás.pinilla@example.com': '130',
#  'paz.robles@example.com': '131',
#  'ceferino.sosa@example.com': '132',
#  'calista.azorin@example.com': '133',
#  'pancho.gomez@example.com': '134',
#  'mercedes.arjona@example.com': '135',
#  'jose miguel.flores@example.com': '136',
#  'ester.corominas@example.com': '137',
#  'ainara.carbó@example.com': '138',
#  'isaías.sola@example.com': '139',
#  'maría fernanda.peinado@example.com': '140',
#  'elvira.carbó@example.com': '141',
#  'amancio.mesa@example.com': '142',
#  'ligia.fiol@example.com': '143',
#  'jessica.herrero@example.com': '144',
#  'eli.carrillo@example.com': '145',
#  'clarisa.armengol@example.com': '146',
#  'tiburcio.pellicer@example.com': '147',
#  'flora.nogueira@example.com': '148',
#  'sosimo.trillo@example.com': '149',
#  'porfirio.segura@example.com': '150',
#  'florina.león@example.com': '151',
#  'zaira.tomás@example.com': '152',
#  'jose luis.bolaños@example.com': '153',
#  'virgilio.hervás@example.com': '154',
#  'ana belén.morcillo@example.com': '155',
#  'ibán.pacheco@example.com': '156',
#  'noé.losa@example.com': '157',
#  'judith.llorente@example.com': '158',
#  'asunción.feijoo@example.com': '159',
#  'flavia.tudela@example.com': '160',
#  'sandalio.hervia@example.com': '161',
#  'cándida.peinado@example.com': '162',
#  'bernarda.núñez@example.com': '163',
#  'wilfredo.lillo@example.com': '164',
#  'jerónimo.carrillo@example.com': '165',
#  'maximiano.carreras@example.com': '166',
#  'maría belén.esteve@example.com': '167',
#  'mamen.tomé@example.com': '168',
#  'dolores.zamorano@example.com': '169',
#  'cornelio.ferrera@example.com': '170',
#  'poncio.escobar@example.com': '171',
#  'leandra.castañeda@example.com': '172',
#  'baltasar.manzano@example.com': '173',
#  'edmundo.tudela@example.com': '174',
#  'aurelio.iriarte@example.com': '175',
#  'ale.carbonell@example.com': '176',
#  'eva.baeza@example.com': '177',
#  'obdulia.mateu@example.com': '178',
#  'jose ramón.carrasco@example.com': '179',
#  'sigfrido.gonzalez@example.com': '180',
#  'manuel.romeu@example.com': '181',
#  'manola.cabezas@example.com': '182',
#  'hipólito.galván@example.com': '183',
#  'carmina.benavides@example.com': '184',
#  'adoración.manuel@example.com': '185',
#  'wilfredo.belda@example.com': '186',
#  'violeta.larrañaga@example.com': '187',
#  'calixto.barreda@example.com': '188',
#  'adelina.mateu@example.com': '189',
#  'urbano.bernat@example.com': '190',
#  'tamara.rosales@example.com': '191',
#  'elisabet.ibáñez@example.com': '192',
#  'jenaro.almansa@example.com': '193',
#  'hortensia.leon@example.com': '194',
#  'maría carmen.díez@example.com': '195',
#  'gerardo.ruano@example.com': '196',
#  'amparo.bou@example.com': '197',
#  'sebastian.mínguez@example.com': '198',
#  'joaquina.valbuena@example.com': '199',
#  'salvador.arco@example.com': '200',
#  'maxi.iniesta@example.com': '201',
#  'paloma.abella@example.com': '202',
#  'godofredo.villegas@example.com': '203',
#  'carmela.castro@example.com': '204',
#  'urbano.tormo@example.com': '205',
#  'maría.alcalá@example.com': '206',
#  'ciro.gomila@example.com': '207',
#  'desiderio.correa@example.com': '208',
#  'lilia.manzanares@example.com': '209',
#  'leandro.ribes@example.com': '210',
#  'elías.baños@example.com': '211',
#  'montserrat.ribera@example.com': '212',
#  'abilio.luna@example.com': '213',
#  'pilar.tovar@example.com': '214',
#  'carmina.pi@example.com': '215',
#  'maura.reig@example.com': '216',
#  'marcela.suárez@example.com': '217',
#  'gracia.cornejo@example.com': '218',
#  'angelino.cases@example.com': '219',
#  'sandra.sacristán@example.com': '220',
#  'juan manuel.nevado@example.com': '221',
#  'rómulo.bernat@example.com': '222',
#  'eugenia.torrents@example.com': '223',
#  'andrés felipe.bayona@example.com': '224',
#  'clímaco.cabrera@example.com': '225',
#  'lázaro.palmer@example.com': '226',
#  'esteban.hidalgo@example.com': '227',
#  'clarisa.escolano@example.com': '228',
#  'cayetano.piñeiro@example.com': '229',
#  'jose angel.valenciano@example.com': '230',
#  'eric.guerra@example.com': '231',
#  'agapito.sola@example.com': '232',
#  'inés.cruz@example.com': '233',
#  'teobaldo.ibáñez@example.com': '234',
#  'rico.palomar@example.com': '235',
#  'juana.marquez@example.com': '236',
#  'paula.priego@example.com': '237',
#  'clarisa.avilés@example.com': '238',
#  'vanesa.macías@example.com': '239',
#  'lorena.cerro@example.com': '240',
#  'lupita.catalá@example.com': '241',
#  'manolo.morillo@example.com': '242',
#  'gabino.font@example.com': '243',
#  'calista.paz@example.com': '244',
#  'manolo.nevado@example.com': '245',
#  'adelina.benet@example.com': '246',
#  'jaime.puerta@example.com': '247',
#  'marianela.juárez@example.com': '248',
#  'pacífica.pera@example.com': '249',
#  'joaquín.soto@example.com': '250',
#  'soledad.mosquera@example.com': '251',
#  'demetrio.chaves@example.com': '252',
#  'david.cabanillas@example.com': '253',
#  'encarnación.raya@example.com': '254',
#  'lino.aparicio@example.com': '255',
#  'isaac.salcedo@example.com': '256',
#  'itziar.pedrero@example.com': '257',
#  'leoncio.falcó@example.com': '258',
#  'miriam.fuertes@example.com': '259',
#  'odalis.guijarro@example.com': '260',
#  'roxana.amigó@example.com': '261',
#  'pepito.gárate@example.com': '262',
#  'alcides.dávila@example.com': '263',
#  'edmundo.robledo@example.com': '264',
#  'mayte.paredes@example.com': '265',
#  'césar.sans@example.com': '266',
#  'encarnacion.aroca@example.com': '267',
#  'violeta.vázquez@example.com': '268',
#  'alejandra.querol@example.com': '269',
#  'cándido.trujillo@example.com': '270',
#  'modesto.colomer@example.com': '271',
#  'edelmira.mariño@example.com': '272',
#  'elodia.ros@example.com': '273',
#  'florina.garrido@example.com': '274',
#  'susanita.gracia@example.com': '275',
#  'pastora.santana@example.com': '276',
#  'luna.bustamante@example.com': '277',
#  'matías.jara@example.com': '278',
#  'ezequiel.sánchez@example.com': '279',
#  'paz.blázquez@example.com': '280',
#  'clemente.peralta@example.com': '281',
#  'maricela.rocha@example.com': '282',
#  'lorena.aznar@example.com': '283',
#  'eli.miguel@example.com': '284',
#  'gala.toledo@example.com': '285',
#  'consuela.gonzalo@example.com': '286',
#  'ramona.amo@example.com': '287',
#  'gema.lastra@example.com': '288',
#  'pascual.aguado@example.com': '289',
#  'eric.pérez@example.com': '290',
#  'manu.anglada@example.com': '291',
#  'bernarda.garrido@example.com': '292',
#  'wilfredo.nogueira@example.com': '293',
#  'clementina.blazquez@example.com': '294',
#  'fabricio.criado@example.com': '295',
#  'gisela.rodrigo@example.com': '296',
#  'vasco.ribas@example.com': '297',
#  'marisol.vila@example.com': '298',
#  'tito.cantero@example.com': '299',
#  'mario.arroyo@example.com': '300',
#  'marcial.galván@example.com': '301',
#  'maría cristina.jaume@example.com': '302',
#  'berta.grau@example.com': '303',
#  'perla.pablo@example.com': '304',
#  'ángel.bermejo@example.com': '305',
#  'leire.rios@example.com': '306',
#  'sandalio.almansa@example.com': '307',
#  'francisco javier.seguí@example.com': '308',
#  'zaira.paredes@example.com': '309',
#  'rafaela.camacho@example.com': '310',
#  'dolores.pérez@example.com': '311',
#  'ruy.menéndez@example.com': '312',
#  'ismael.mínguez@example.com': '313',
#  'olivia.coloma@example.com': '314',
#  'eligia.coronado@example.com': '315',
#  'gabriela.benet@example.com': '316',
#  'maría teresa.uribe@example.com': '317',
#  'sofía.moraleda@example.com': '318',
#  'eulalia.molina@example.com': '319',
#  'borja.somoza@example.com': '320',
#  'marcio.llobet@example.com': '321',
#  'pastor.vera@example.com': '322',
#  'rosario.bosch@example.com': '323',
#  'anunciación.planas@example.com': '324',
#  'casandra.armengol@example.com': '325',
#  'nélida.fabra@example.com': '326',
#  'bernabé.sanjuan@example.com': '327',
#  'trini.nuñez@example.com': '328',
#  'cesar.vargas@example.com': '329',
#  'aníbal.huguet@example.com': '330',
#  'federico.pascual@example.com': '331',
#  'lorenzo.ponce@example.com': '332',
#  'nilo.badía@example.com': '333',
#  'ciríaco.pomares@example.com': '334',
#  'lourdes.conesa@example.com': '335',
#  'martín.pou@example.com': '336',
#  'renato.moya@example.com': '337',
#  'herminia.zurita@example.com': '338',
#  'iker.noguera@example.com': '339',
#  'rafaela.cadenas@example.com': '340',
#  'nicodemo.castro@example.com': '341',
#  'fabio.cámara@example.com': '342',
#  'jimena.daza@example.com': '343',
#  'armando.reig@example.com': '344',
#  'loida.gámez@example.com': '345',
#  'emiliana.lópez@example.com': '346',
#  'miguela.sanchez@example.com': '347',
#  'jorge.mendoza@example.com': '348',
#  'silvio.cáceres@example.com': '349',
#  'baldomero.terrón@example.com': '350',
#  'ascensión.casanovas@example.com': '351',
#  'vicenta.vilanova@example.com': '352',
#  'amando.ribera@example.com': '353',
#  'ceferino.perera@example.com': '354',
#  'melchor.cabeza@example.com': '355',
#  'emigdio.arenas@example.com': '356',
#  'paula.sureda@example.com': '357',
#  'emilio.somoza@example.com': '358',
#  'adelardo.bernad@example.com': '359',
#  'ildefonso.conde@example.com': '360',
#  'lucía.álamo@example.com': '361',
#  'maura.maldonado@example.com': '362',
#  'domingo.asenjo@example.com': '363',
#  'feliciana.sebastián@example.com': '364',
#  'piedad.valero@example.com': '365',
#  'alcides.villalba@example.com': '366',
#  'abel.osorio@example.com': '367',
#  'sigfrido.exposito@example.com': '368',
#  'borja.zorrilla@example.com': '369',
#  'miriam.vera@example.com': '370',
#  'alcides.palau@example.com': '371',
#  'eusebia.calleja@example.com': '372',
#  'macaria.márquez@example.com': '373',
#  'pastor.nevado@example.com': '374',
#  'alejandra.esparza@example.com': '375',
#  'bernardino.seco@example.com': '376',
#  'heriberto.arranz@example.com': '377',
#  'martín.villalba@example.com': '378',
#  'ofelia.sáenz@example.com': '379',
#  'marisa.feijoo@example.com': '380',
#  'quirino.rueda@example.com': '381',
#  'mar.sabater@example.com': '382',
#  'nayara.vives@example.com': '383',
#  'eligia.escribano@example.com': '384',
#  'gertrudis.marqués@example.com': '385',
#  'vicente.ortega@example.com': '386',
#  'febe.ramis@example.com': '387',
#  'nicolasa.cuesta@example.com': '388',
#  'bonifacio.guzman@example.com': '389',
#  'quique.paredes@example.com': '390',
#  'claudia.antúnez@example.com': '391',
#  'iris.sandoval@example.com': '392',
#  'ramiro.saldaña@example.com': '393',
#  'consuela.cervantes@example.com': '394',
#  'rómulo.miralles@example.com': '395',
#  'josep.carballo@example.com': '396',
#  'gilberto.valera@example.com': '397',
#  'xiomara.carranza@example.com': '398',
#  'emma.machado@example.com': '399',
#  'amor.folch@example.com': '400',
#  'reyna.benavent@example.com': '401',
#  'nélida.montenegro@example.com': '402',
#  'leire.barón@example.com': '403',
#  'leonor.dávila@example.com': '404',
#  'ana.amo@example.com': '405',
#  'constanza.peinado@example.com': '406',
#  'carmen.castilla@example.com': '407',
#  'chema.bastida@example.com': '408',
#  'maría josé.recio@example.com': '409',
#  'felisa.benavent@example.com': '410',
#  'efraín.roselló@example.com': '411',
#  'ruperta.baquero@example.com': '412',
#  'aura.coronado@example.com': '413',
#  'josué.ferrándiz@example.com': '414',
#  'marcio.bueno@example.com': '415',
#  'florentino.correa@example.com': '416',
#  'etelvina.nebot@example.com': '417',
#  'cintia.armengol@example.com': '418',
#  'américo.valenciano@example.com': '419',
#  'marciano.tomas@example.com': '420',
#  'severo.tomé@example.com': '421',
#  'noé.cobo@example.com': '422',
#  'lina.montaña@example.com': '423',
#  'rosalinda.ojeda@example.com': '424',
#  'eladio.pellicer@example.com': '425',
#  'rosenda.cuesta@example.com': '426',
#  'rubén.vega@example.com': '427',
#  'jose angel.garrido@example.com': '428',
#  'edelmira.sosa@example.com': '429',
#  'sofía.lamas@example.com': '430',
#  'maría cristina.quintana@example.com': '431',
#  'salvador.azcona@example.com': '432',
#  'guiomar.pareja@example.com': '433',
#  'candelario.pomares@example.com': '434',
#  'maría cristina.losa@example.com': '435',
#  'estrella.carrera@example.com': '436',
#  'cleto.prada@example.com': '437',
#  'norberto.pavón@example.com': '438',
#  'heliodoro.verdú@example.com': '439',
#  'apolinar.arrieta@example.com': '440',
#  'leyre.mínguez@example.com': '441',
#  'aurelia.saura@example.com': '442',
#  'emperatriz.montalbán@example.com': '443',
#  'anunciación.vergara@example.com': '444',
#  'ale.pedrosa@example.com': '445',
#  'damián.riera@example.com': '446',
#  'natividad.amor@example.com': '447',
#  'isa.herrera@example.com': '448',
#  'juanita.canet@example.com': '449',
#  'seve.frías@example.com': '450',
#  'matilde.soto@example.com': '451',
#  'magdalena.barrios@example.com': '452',
#  'mauricio.duran@example.com': '453',
#  'berta.noriega@example.com': '454',
#  'gregorio.hoz@example.com': '455',
#  'marc.gomila@example.com': '456',
#  'manuel.malo@example.com': '457',
#  'paco.llanos@example.com': '458',
#  'consuela.pino@example.com': '459',
#  'ruperto.ochoa@example.com': '460',
#  'iker.franch@example.com': '461',
#  'kike.llabrés@example.com': '462',
#  'haydée.gonzalez@example.com': '463',
#  'baldomero.cabrera@example.com': '464',
#  'maría manuela.cervantes@example.com': '465',
#  'carmelita.cruz@example.com': '466',
#  'heraclio.madrigal@example.com': '467',
#  'chuy.guerra@example.com': '468',
#  'gabino.rios@example.com': '469',
#  'gabriel.arce@example.com': '470',
#  'régulo.valbuena@example.com': '471',
#  'agapito.martín@example.com': '472',
#  'custodio.naranjo@example.com': '473',
#  'felipa.zamora@example.com': '474',
#  'eloy.varela@example.com': '475',
#  'guadalupe.capdevila@example.com': '476',
#  'lina.estrada@example.com': '477',
#  'nicolás.marquez@example.com': '478',
#  'marita.ferrando@example.com': '479',
#  'haydée.bustos@example.com': '480',
#  'enrique.tejada@example.com': '481',
#  'jose ramón.agudo@example.com': '482',
#  'jonatan.salom@example.com': '483',
#  'constanza.alberdi@example.com': '484',
#  'diego.solana@example.com': '485',
#  'feliciana.marquez@example.com': '486',
#  'eloísa.pereira@example.com': '487',
#  'nidia.gil@example.com': '488',
#  'irma.bilbao@example.com': '489',
#  'belén.pardo@example.com': '490',
#  'cintia.caparrós@example.com': '491',
#  'brunilda.conde@example.com': '492',
#  'irma.fuertes@example.com': '493',
#  'amaya.bou@example.com': '494',
#  'armida.ribes@example.com': '495',
#  'mario.almeida@example.com': '496',
#  'olga.acero@example.com': '497',
#  'benito.bayón@example.com': '498',
#  'agustina.angulo@example.com': '499',
#  'luisina.rivera@example.com': '500',
#  'yéssica.pina@example.com': '501',
#  'isabela.cañas@example.com': '502',
#  'pablo.carrasco@example.com': '503',
#  'abigaíl.rodrigo@example.com': '504',
#  'palmira.gras@example.com': '505',
#  'osvaldo.cortina@example.com': '506',
#  'sara.carbajo@example.com': '507',
#  'gertrudis.rius@example.com': '508',
#  'sol.alcázar@example.com': '509',
#  'victoriano.atienza@example.com': '510',
#  'arsenio.quesada@example.com': '511',
#  'calista.gaya@example.com': '512',
#  'maura.barbero@example.com': '513',
#  'lupita.montaña@example.com': '514',
#  'sarita.clemente@example.com': '515',
#  'azahar.giner@example.com': '516',
#  'domitila.díez@example.com': '517',
#  'teófilo.valcárcel@example.com': '518',
#  'omar.piquer@example.com': '519',
#  'melchor.rico@example.com': '520',
#  'brígida.sáenz@example.com': '521',
#  'ernesto.sierra@example.com': '522',
#  'chita.rey@example.com': '523',
#  'cecilia.cañete@example.com': '524',
#  'cayetano.sandoval@example.com': '525',
#  'cirino.farré@example.com': '526',
#  'rené.ariza@example.com': '527',
#  'godofredo.gaya@example.com': '528',
#  'ruth.méndez@example.com': '529',
#  'violeta.alcántara@example.com': '530',
#  'goyo.carpio@example.com': '531',
#  'ricardo.solano@example.com': '532',
#  'plinio.mendez@example.com': '533',
#  'armida.valencia@example.com': '534',
#  'nieves.soria@example.com': '535',
#  'miguel.frutos@example.com': '536',
#  'carolina.rios@example.com': '537',
#  'gustavo.murcia@example.com': '538',
#  'clotilde.hoyos@example.com': '539',
#  'fátima.nebot@example.com': '540',
#  'paca.torres@example.com': '541',
#  'felisa.trujillo@example.com': '542',
#  'lola.torres@example.com': '543',
#  'tamara.barral@example.com': '544',
#  'primitiva.benavente@example.com': '545',
#  'guiomar.atienza@example.com': '546',
#  'seve.cervantes@example.com': '547',
#  'jerónimo.bayo@example.com': '548',
#  'agapito.gil@example.com': '549',
#  'raúl.barrena@example.com': '550',
#  'griselda.tomas@example.com': '551',
#  'alcides.agudo@example.com': '552',
#  'lorenza.llobet@example.com': '553',
#  'luciano.alemany@example.com': '554',
#  'josé.ros@example.com': '555',
#  'virginia.escobar@example.com': '556',
#  'gregorio.zurita@example.com': '557',
#  'cayetano.perea@example.com': '558',
#  'ángel.hervia@example.com': '559',
#  'regina.berrocal@example.com': '560',
#  'rosa.angulo@example.com': '561',
#  'basilio.agustí@example.com': '562',
#  'rosa.bustos@example.com': '563',
#  'zaira.arnau@example.com': '564',
#  'valentina.talavera@example.com': '565',
#  'lisandro.aparicio@example.com': '566',
#  'remedios.miranda@example.com': '567',
#  'hipólito.cobos@example.com': '568',
#  'marcelino.cámara@example.com': '569',
#  'claudia.porcel@example.com': '570',
#  'calixta.mármol@example.com': '571',
#  'osvaldo.baeza@example.com': '572',
#  'maría josé.puente@example.com': '573',
#  'nacho.andreu@example.com': '574',
#  'miguela.sanjuan@example.com': '575',
#  'pelayo.perez@example.com': '576',
#  'irma.pinto@example.com': '577',
#  'leyre.beltrán@example.com': '578',
#  'fabiana.correa@example.com': '579',
#  'maximiliano.palomo@example.com': '580',
#  'adelardo.mendez@example.com': '581',
#  'maría.lerma@example.com': '582',
#  'cecilia.vila@example.com': '583',
#  'amancio.borrás@example.com': '584',
#  'albano.manzanares@example.com': '585',
#  'melania.blazquez@example.com': '586',
#  'celia.herrero@example.com': '587',
#  'fortunato.pintor@example.com': '588',
#  'julio césar.mascaró@example.com': '589',
#  'esteban.barroso@example.com': '590',
#  'leoncio.robledo@example.com': '591',
#  'micaela.benítez@example.com': '592',
#  'jose manuel.valcárcel@example.com': '593',
#  'marco.agudo@example.com': '594',
#  'nazaret.pinto@example.com': '595',
#  'olalla.cerdán@example.com': '596',
#  'lupe.tudela@example.com': '597',
#  'merche.herrera@example.com': '598',
#  'lisandro.pozo@example.com': '599',
#  'caridad.escolano@example.com': '600',
#  'íñigo.gallego@example.com': '601',
#  'lupe.bayón@example.com': '602',
#  'natalia.rebollo@example.com': '603',
#  'emilio.mateo@example.com': '604',
#  'genoveva.correa@example.com': '605',
#  'montserrat.pi@example.com': '606',
#  'elba.tello@example.com': '607',
#  'bienvenida.velázquez@example.com': '608',
#  'morena.palomares@example.com': '609',
#  'octavia.blázquez@example.com': '610',
#  'jose ramón.padilla@example.com': '611',
#  'emperatriz.arregui@example.com': '612',
#  'filomena.pulido@example.com': '613',
#  'margarita.villena@example.com': '614',
#  'javiera.giner@example.com': '615',
#  'amador.tolosa@example.com': '616',
#  'severo.boada@example.com': '617',
#  'luna.cifuentes@example.com': '618',
#  'olegario.sarabia@example.com': '619',
#  'azahar.tomas@example.com': '620',
#  'víctor.montaña@example.com': '621',
#  'arsenio.cardona@example.com': '622',
#  'fidel.hervás@example.com': '623',
#  'malena.figueroa@example.com': '624',
#  'iker.fuster@example.com': '625',
#  'juliana.barros@example.com': '626',
#  'nerea.estévez@example.com': '627',
#  'haroldo.seco@example.com': '628',
#  'feliciana.millán@example.com': '629',
#  'emiliana.poza@example.com': '630',
#  'pablo.ortiz@example.com': '631',
#  'esmeralda.duque@example.com': '632',
#  'dominga.blazquez@example.com': '633',
#  'epifanio.vicente@example.com': '634',
#  'maxi.sanmartín@example.com': '635',
#  'rosenda.palomar@example.com': '636',
#  'amada.cerezo@example.com': '637',
#  'priscila.saldaña@example.com': '638',
#  'celestino.anguita@example.com': '639',
#  'jafet.malo@example.com': '640',
#  'daniel.carbonell@example.com': '641',
#  'malena.orozco@example.com': '642',
#  'emilia.roman@example.com': '643',
#  'emilio.gabaldón@example.com': '644',
#  'noa.barranco@example.com': '645',
#  'berta.lucas@example.com': '646',
#  'florentino.morales@example.com': '647',
#  'luís.mancebo@example.com': '648',
#  'iris.bustos@example.com': '649',
#  'maricela.reina@example.com': '650',
#  'modesto.huertas@example.com': '651',
#  'inmaculada.pozo@example.com': '652',
#  'crescencia.leiva@example.com': '653',
#  'narcisa.buendía@example.com': '654',
#  'maribel.lobo@example.com': '655',
#  'saturnina.peinado@example.com': '656',
#  'ruperta.buendía@example.com': '657',
#  'álvaro.palma@example.com': '658',
#  'natalia.puga@example.com': '659',
#  'timoteo.galán@example.com': '660',
#  'mohamed.luque@example.com': '661',
#  'amada.nuñez@example.com': '662',
#  'maría belén.atienza@example.com': '663',
#  'eugenia.segura@example.com': '664',
#  'marciano.cuenca@example.com': '665',
#  'sarita.lledó@example.com': '666',
#  'poncio.ibáñez@example.com': '667',
#  'graciana.dalmau@example.com': '668',
#  'eufemia.mayoral@example.com': '669',
#  'marisol.guillén@example.com': '670',
#  'ciriaco.bustamante@example.com': '671',
#  'albina.bermejo@example.com': '672',
#  'jaime.vives@example.com': '673',
#  'agapito.aguiló@example.com': '674',
#  'olga.carreño@example.com': '675',
#  'telmo.catalán@example.com': '676',
#  'noelia.calatayud@example.com': '677',
#  'quirino.martínez@example.com': '678',
#  'inés.clavero@example.com': '679',
#  'ignacio.cordero@example.com': '680',
#  'timoteo.miranda@example.com': '681',
#  'jose miguel.lluch@example.com': '682',
#  'jose ramón.lópez@example.com': '683',
#  'jessica.amor@example.com': '684',
#  'genoveva.mata@example.com': '685',
#  'elvira.vergara@example.com': '686',
#  'miguela.heras@example.com': '687',
#  'dorotea.belda@example.com': '688',
#  'eligio.pombo@example.com': '689',
#  'cloe.rivero@example.com': '690',
#  'isabela.duque@example.com': '691',
#  'maría luisa.beltran@example.com': '692',
#  'borja.alcalá@example.com': '693',
#  'aníbal.barrena@example.com': '694',
#  'rómulo.velázquez@example.com': '695',
#  'teo.quesada@example.com': '696',
#  'brunilda.corominas@example.com': '697',
#  'martín.bermúdez@example.com': '698',
#  'ulises.gómez@example.com': '699',
#  'chema.rovira@example.com': '700',
#  'emma.ballesteros@example.com': '701',
#  'laura.cervantes@example.com': '702',
#  'azeneth.villar@example.com': '703',
#  'lorena.jove@example.com': '704',
#  'edmundo.leiva@example.com': '705',
#  'desiderio.andreu@example.com': '706',
#  'juan josé.benítez@example.com': '707',
#  'ariadna.palomino@example.com': '708',
#  'rosa maría.diaz@example.com': '709',
#  'rosa.aranda@example.com': '710',
#  'xiomara.rius@example.com': '711',
#  'miguel.linares@example.com': '712',
#  'maría.morán@example.com': '713',
#  'yago.aguiló@example.com': '714',
#  'lupe.mateu@example.com': '715',
#  'jose carlos.simó@example.com': '716',
#  'osvaldo.agustí@example.com': '717',
#  'abel.peñalver@example.com': '718',
#  'mariana.blazquez@example.com': '719',
#  'anselma.cañellas@example.com': '720',
#  'bernabé.royo@example.com': '721',
#  'eladio.guzmán@example.com': '722',
#  'rubén.morera@example.com': '723',
#  'fidel.sancho@example.com': '724',
#  'santos.carrillo@example.com': '725',
#  'maría luisa.galiano@example.com': '726',
#  'cipriano.criado@example.com': '727',
#  'leonor.hurtado@example.com': '728',
#  'ruy.vilanova@example.com': '729',
#  'félix.anguita@example.com': '730',
#  'rita.santamaria@example.com': '731',
#  'carmelita.iborra@example.com': '732',
#  'palmira.pérez@example.com': '733',
#  'vicente.castells@example.com': '734',
#  'rebeca.mármol@example.com': '735',
#  'íñigo.ayuso@example.com': '736',
#  'consuela.rosselló@example.com': '737',
#  'ruperto.valderrama@example.com': '738',
#  'estefanía.hoyos@example.com': '739',
#  'andrea.requena@example.com': '740',
#  'rodolfo.cervantes@example.com': '741',
#  'nidia.aliaga@example.com': '742',
#  'clarisa.vallés@example.com': '743',
#  'julián.escolano@example.com': '744',
#  'edelmira.gilabert@example.com': '745',
#  'agustina.ávila@example.com': '746',
#  'daniela.guerrero@example.com': '747',
#  'cornelio.huguet@example.com': '748',
#  'juan pablo.barba@example.com': '749',
#  'isidoro.pont@example.com': '750',
#  'primitiva.durán@example.com': '751',
#  'amaro.ortiz@example.com': '752',
#  'cintia.cisneros@example.com': '753',
#  'godofredo.ugarte@example.com': '754',
#  'gabino.trujillo@example.com': '755',
#  'noé.elías@example.com': '756',
#  'eusebio.cifuentes@example.com': '757',
#  'raquel.zorrilla@example.com': '758',
#  'camilo.pereira@example.com': '759',
#  'fausto.rueda@example.com': '760',
#  'amanda.molins@example.com': '761',
#  'dolores.echevarría@example.com': '762',
#  'macarena.mariño@example.com': '763',
#  'constanza.posada@example.com': '764',
#  'maría manuela.antúnez@example.com': '765',
#  'maximino.giner@example.com': '766',
#  'cristóbal.valderrama@example.com': '767',
#  'marcia.bermejo@example.com': '768',
#  'chus.narváez@example.com': '769',
#  'borja.ordóñez@example.com': '770',
#  'cándido.abella@example.com': '771',
#  'urbano.rivas@example.com': '772',
#  'reyes.ortega@example.com': '773',
#  'cosme.tello@example.com': '774',
#  'crescencia.gomis@example.com': '775',
#  'candelario.aragonés@example.com': '776',
#  'melchor.julián@example.com': '777',
#  'candelario.nogués@example.com': '778',
#  'carla.buendía@example.com': '779',
#  'encarna.tolosa@example.com': '780',
#  'toño.crespo@example.com': '781',
#  'natanael.fuertes@example.com': '782',
#  'sebastián.lara@example.com': '783',
#  'manuel.gámez@example.com': '784',
#  'poncio.acevedo@example.com': '785',
#  'macario.tenorio@example.com': '786',
#  'amancio.gabaldón@example.com': '787',
#  'david.mendez@example.com': '788',
#  'roldán.esteban@example.com': '789',
#  'rico.peiró@example.com': '790',
#  'arsenio.lago@example.com': '791',
#  'cintia.barrio@example.com': '792',
#  'josefina.caballero@example.com': '793',
#  'omar.riba@example.com': '794',
#  'silvio.taboada@example.com': '795',
#  'jonatan.tamayo@example.com': '796',
#  'edmundo.arnau@example.com': '797',
#  'juan.montenegro@example.com': '798',
#  'yaiza.bautista@example.com': '799',
#  'cayetana.puerta@example.com': '800',
#  'rocío.llorente@example.com': '801',
#  'claudia.cabrera@example.com': '802',
#  'rufina.núñez@example.com': '803',
#  'concha.suárez@example.com': '804',
#  'leoncio.quintana@example.com': '805',
#  'emelina.querol@example.com': '806',
#  'tamara.muñoz@example.com': '807',
#  'augusto.talavera@example.com': '808',
#  'teófila.perales@example.com': '809',
#  'olimpia.mateo@example.com': '810',
#  'isidora.cabello@example.com': '811',
#  'javier.cañizares@example.com': '812',
#  'mar.salazar@example.com': '813',
#  'miguel ángel.leon@example.com': '814',
#  'elodia.borrell@example.com': '815',
#  'héctor.ramírez@example.com': '816',
#  'martina.villalonga@example.com': '817',
#  'otilia.barbero@example.com': '818',
#  'federico.bastida@example.com': '819',
#  'pepita.font@example.com': '820',
#  'josep.aparicio@example.com': '821',
#  'anselma.puente@example.com': '822',
#  'amaya.salmerón@example.com': '823',
#  'sabina.sánchez@example.com': '824',
#  'pancho.ocaña@example.com': '825',
#  'tere.jordán@example.com': '826',
#  'jennifer.botella@example.com': '827',
#  'rolando.ayala@example.com': '828',
#  'concha.gargallo@example.com': '829',
#  'flor.gomis@example.com': '830',
#  'rosaura.agullo@example.com': '831',
#  'eligio.duran@example.com': '832',
#  'adán.goicoechea@example.com': '833',
#  'noa.mayoral@example.com': '834',
#  'leire.llopis@example.com': '835',
#  'azahar.puerta@example.com': '836',
#  'adrián.vidal@example.com': '837',
#  'pía.perelló@example.com': '838',
#  'leonel.morcillo@example.com': '839',
#  'juan carlos.martín@example.com': '840',
#  'noa.quintero@example.com': '841',
#  'isa.chaves@example.com': '842',
#  'juan antonio.riquelme@example.com': '843',
#  'concha.falcó@example.com': '844',
#  'leyre.girón@example.com': '845',
#  'hilda.palmer@example.com': '846',
#  'sarita.escrivá@example.com': '847',
#  'adriana.castellanos@example.com': '848',
#  'trinidad.narváez@example.com': '849',
#  'iván.padilla@example.com': '850',
#  'salomé.melero@example.com': '851',
#  'delfina.mariscal@example.com': '852',
#  'guiomar.vall@example.com': '853',
#  'isa.pizarro@example.com': '854',
#  'severiano.balaguer@example.com': '855',
#  'eutropio.cervantes@example.com': '856',
#  'octavio.recio@example.com': '857',
#  'rosalía.escribano@example.com': '858',
#  'galo.millán@example.com': '859',
#  'adalberto.sans@example.com': '860',
#  'albina.pla@example.com': '861',
#  'alberto.montserrat@example.com': '862',
#  'bernarda.farré@example.com': '863',
#  'adalberto.ibarra@example.com': '864',
#  'saturnina.ocaña@example.com': '865',
#  'cristian.pla@example.com': '866',
#  'artemio.martí@example.com': '867',
#  'xavier.viña@example.com': '868',
#  'eloy.noriega@example.com': '869',
#  'amelia.palomar@example.com': '870',
#  'alfredo.vargas@example.com': '871',
#  'felicidad.jaume@example.com': '872',
#  'estrella.atienza@example.com': '873',
#  'atilio.campoy@example.com': '874',
#  'alex.asensio@example.com': '875',
#  'sigfrido.saldaña@example.com': '876',
#  'ezequiel.fuertes@example.com': '877',
#  'gisela.cabrero@example.com': '878',
#  'julián.cerro@example.com': '879',
#  'trini.calvo@example.com': '880',
#  'esmeralda.carranza@example.com': '881',
#  'emelina.folch@example.com': '882',
#  'paz.zabala@example.com': '883',
#  'pepito.redondo@example.com': '884',
#  'aníbal.valderrama@example.com': '885',
#  'cipriano.vidal@example.com': '886',
#  'manu.laguna@example.com': '887',
#  'cornelio.díaz@example.com': '888',
#  'reyes.manso@example.com': '889',
#  'emiliano.donaire@example.com': '890',
#  'tere.río@example.com': '891',
#  'salomón.sastre@example.com': '892',
#  'rogelio.tejera@example.com': '893',
#  'florencia.diaz@example.com': '894',
#  'josefa.barral@example.com': '895',
#  'rafaela.cuervo@example.com': '896',
#  'viviana.tolosa@example.com': '897',
#  'reynaldo.palmer@example.com': '898',
#  'rosalía.castrillo@example.com': '899',
#  'amarilis.carbajo@example.com': '900',
#  'valero.arteaga@example.com': '901',
#  'corona.goicoechea@example.com': '902',
#  'javiera.bustos@example.com': '903',
#  'lucía.ibarra@example.com': '904',
#  'gracia.plaza@example.com': '905',
#  'pascuala.ballester@example.com': '906',
#  'faustino.vega@example.com': '907',
#  'reyes.valcárcel@example.com': '908',
#  'carlito.tur@example.com': '909',
#  'natalio.lobo@example.com': '910',
#  'jacinto.pinedo@example.com': '911',
#  'joel.bermúdez@example.com': '912',
#  'nicolasa.samper@example.com': '913',
#  'andrea.salvador@example.com': '914',
#  'seve.araujo@example.com': '915',
#  'aarón.bou@example.com': '916',
#  'chita.gabaldón@example.com': '917',
#  'yago.nogueira@example.com': '918',
#  'baltasar.gisbert@example.com': '919',
#  'prudencio.santamaria@example.com': '920',
#  'pedro.manzanares@example.com': '921',
#  'raúl.camino@example.com': '922',
#  'fidel.ugarte@example.com': '923',
#  'emiliana.ferrández@example.com': '924',
#  'reyes.pozo@example.com': '925',
#  'cándido.ribas@example.com': '926',
#  'evita.casal@example.com': '927',
#  'virgilio.sebastián@example.com': '928',
#  'adalberto.atienza@example.com': '929',
#  'toribio.tomas@example.com': '930',
#  'mercedes.elorza@example.com': '931',
#  'gema.montserrat@example.com': '932',
#  'yolanda.hurtado@example.com': '933',
#  'olegario.mariscal@example.com': '934',
#  'juana.vila@example.com': '935',
#  'judith.mir@example.com': '936',
#  'carolina.gelabert@example.com': '937',
#  'etelvina.manso@example.com': '938',
#  'áfrica.cazorla@example.com': '939',
#  'florentina.enríquez@example.com': '940',
#  'joaquina.mora@example.com': '941',
#  'maría.ortuño@example.com': '942',
#  'dafne.rincón@example.com': '943',
#  'telmo.alberto@example.com': '944',
#  'amador.piquer@example.com': '945',
#  'herminia.barbero@example.com': '946',
#  'isabela.iglesia@example.com': '947',
#  'bernabé.marquez@example.com': '948',
#  'imelda.gomez@example.com': '949',
#  'baltasar.alberto@example.com': '950',
#  'hermenegildo.salazar@example.com': '951',
#  'carina.ferrándiz@example.com': '952',
#  'guillermo.mariscal@example.com': '953',
#  'isabela.benavente@example.com': '954',
#  'fulgencio.vilaplana@example.com': '955',
#  'apolinar.romero@example.com': '956',
#  'raquel.jara@example.com': '957',
#  'íngrid.mora@example.com': '958',
#  'maría ángeles.mascaró@example.com': '959',
#  'constanza.palma@example.com': '960',
#  'gerónimo.viñas@example.com': '961',
#  'brunilda.quintanilla@example.com': '962',
#  'natanael.palomo@example.com': '963',
#  'marina.taboada@example.com': '964',
#  'palmira.agullo@example.com': '965',
#  'felisa.hervás@example.com': '966',
#  'asunción.perera@example.com': '967',
#  'apolonia.salinas@example.com': '968',
#  'manu.fernández@example.com': '969',
#  'celestino.báez@example.com': '970',
#  'maría teresa.aguilera@example.com': '971',
#  'teobaldo.calleja@example.com': '972',
#  'patricia.rozas@example.com': '973',
#  'candelario.ballester@example.com': '974',
#  'josé.bejarano@example.com': '975',
#  'javier.jordán@example.com': '976',
#  'virgilio.quiroga@example.com': '977',
#  'ale.porras@example.com': '978',
#  'bienvenida.aguado@example.com': '979',
#  'curro.manjón@example.com': '980',
#  'marcial.bolaños@example.com': '981',
#  'paca.anguita@example.com': '982',
#  'bibiana.gimeno@example.com': '983',
#  'rosendo.marquez@example.com': '984',
#  'aitor.cid@example.com': '985',
#  'che.mayol@example.com': '986',
#  'manuela.núñez@example.com': '987',
#  'vicenta.vila@example.com': '988',
#  'carmela.serra@example.com': '989',
#  'custodia.torrens@example.com': '990',
#  'pepe.castellanos@example.com': '991',
#  'joel.cabo@example.com': '992',
#  'virgilio.moya@example.com': '993',
#  'pánfilo.molina@example.com': '994',
#  'felipa.rubio@example.com': '995',
#  'plácido.cañizares@example.com': '996',
#  'natanael.tena@example.com': '997',
#  'césar.echevarría@example.com': '998',
#  'enrique.ferrándiz@example.com': '999',
#  'soraya.benito@example.com': '1000',
#  ...}

# %%
# Sacamos el id de hotel de la tabla de hoteles
cur.execute("SELECT nombre_hotel, id_hotel FROM hoteles")
dictio_hoteles = dict(cur.fetchall())
dictio_hoteles
# Out:
# {'Hotel Monte Verde': '1',
#  'Hotel Brisas del Mar': '2',
#  'Hotel Camino del Sol': '3',
#  'Hotel Puerta del Cielo': '4',
#  'Hotel Encanto Real': '5',
#  'Palacio del Sol': '6',
#  'Hotel Jardines del Rey': '7',
#  'Hotel Las Estrellas': '8',
#  'Gran Hotel Madrid': '9',
#  'Hotel Torre Dorada': '10',
#  'Hotel Palacio Imperial': '11',
#  'Hotel Luz de Madrid': '12',
#  'Hotel Los Almendros': '13',
#  'Hotel Sol y Luna': '14',
#  'Hotel Mirador Real': '15',
#  'Hotel Rincón Sereno': '16',
#  'Hotel Vista Alegre': '17',
#  'Hotel Costa Azul': '18',
#  'Hotel Maravilla Real': '19',
#  'ibis Styles Madrid Prado': '20',
#  'ibis Styles Madrid Centro Maravillas': '21',
#  'ibis Madrid Centro las Ventas': '22',
#  'ibis budget Madrid Centro las Ventas': '23',
#  'ibis Styles Madrid City Las Ventas': '24',
#  'ibis budget Madrid Calle Alcalá': '25',
#  'ibis Madrid Calle Alcalá': '26',
#  'ibis budget Madrid Vallecas': '27',
#  'ibis Madrid Getafe': '28',
#  'ibis Madrid Aeropuerto Barajas': '29'}

# %%
print(dictio_hoteles.keys())  # Verifica que la clave realmente está en el diccionario
print(dictio_clientes.keys())
# Out:
# dict_keys(['Hotel Monte Verde', 'Hotel Brisas del Mar', 'Hotel Camino del Sol', 'Hotel Puerta del Cielo', 'Hotel Encanto Real', 'Palacio del Sol', 'Hotel Jardines del Rey', 'Hotel Las Estrellas', 'Gran Hotel Madrid', 'Hotel Torre Dorada', 'Hotel Palacio Imperial', 'Hotel Luz de Madrid', 'Hotel Los Almendros', 'Hotel Sol y Luna', 'Hotel Mirador Real', 'Hotel Rincón Sereno', 'Hotel Vista Alegre', 'Hotel Costa Azul', 'Hotel Maravilla Real', 'ibis Styles Madrid Prado', 'ibis Styles Madrid Centro Maravillas', 'ibis Madrid Centro las Ventas', 'ibis budget Madrid Centro las Ventas', 'ibis Styles Madrid City Las Ventas', 'ibis budget Madrid Calle Alcalá', 'ibis Madrid Calle Alcalá', 'ibis budget Madrid Vallecas', 'ibis Madrid Getafe', 'ibis Madrid Aeropuerto Barajas'])
# dict_keys(['maite.calatayud@example.com', 'tecla.bonet@example.com', 'amílcar.andrés@example.com', 'joan.vazquez@example.com', 'chelo.flor@example.com', 'dolores.lobo@example.com', 'noé.lobo@example.com', 'omar.lamas@example.com', 'ágata.pinedo@example.com', 'julie.baños@example.com', 'javier.mancebo@example.com', 'rita.guerrero@example.com', 'ricardo.lobo@example.com', 'perlita.patiño@example.com', 'pedro.gallego@example.com', 'judith.bellido@example.com', 'francisco javier.hierro@example.com', 'reynaldo.lerma@example.com', 'felicidad.gimenez@example.com', 'pía.barba@example.com', 'amílcar.moles@example.com', 'blas.galván@example.com', 'claudia.miranda@example.com', 'fernanda.segarra@example.com', 'emilio.huerta@example.com', 'bárbara.jódar@example.com', 'emiliano.vergara@example.com', 'marisol.arévalo@example.com', 'ezequiel.cuesta@example.com', 'telmo.bartolomé@example.com', 'débora.solé@example.com', 'darío.lasa@example.com', 'fausto.santiago@example.com', 'lorenza.lago@example.com', 'anunciación.flor@example.com', 'maría belén.cuéllar@example.com', 'amaya.aliaga@example.com', 'jose angel.bermúdez@example.com', 'berta.casas@example.com', 'salud.rocha@example.com', 'úrsula.font@example.com', 'sabas.perea@example.com', 'asunción.sanmiguel@example.com', 'jafet.baró@example.com', 'adrián.belda@example.com', 'benigno.granados@example.com', 'amílcar.murillo@example.com', 'jordán.lopez@example.com', 'sofía.suárez@example.com', 'ainara.ramírez@example.com', 'segismundo.solera@example.com', 'luisa.nicolau@example.com', 'césar.ibarra@example.com', 'brunilda.sanabria@example.com', 'gervasio.lopez@example.com', 'sandra.benet@example.com', 'calixta.alcolea@example.com', 'ángeles.guzmán@example.com', 'salvador.barral@example.com', 'abilio.portero@example.com', 'josefina.torrecilla@example.com', 'manu.gelabert@example.com', 'cruz.barrera@example.com', 'joel.quintanilla@example.com', 'aníbal.bilbao@example.com', 'juan carlos.fuente@example.com', 'ignacio.velasco@example.com', 'paco.bayona@example.com', 'rafael.lópez@example.com', 'perla.mate@example.com', 'olga.marí@example.com', 'cristóbal.cañizares@example.com', 'humberto.novoa@example.com', 'fabiana.laguna@example.com', 'teo.lloret@example.com', 'nazario.castrillo@example.com', 'juan francisco.cuéllar@example.com', 'jessica.company@example.com', 'eusebio.ropero@example.com', 'mario.pastor@example.com', 'paulino.ramos@example.com', 'jordi.cámara@example.com', 'amador.escobar@example.com', 'nazaret.requena@example.com', 'otilia.goñi@example.com', 'georgina.ferrando@example.com', 'león.baños@example.com', 'león.ortega@example.com', 'salomón.muñoz@example.com', 'david.julián@example.com', 'corona.falcón@example.com', 'marcelo.vendrell@example.com', 'sebastian.morera@example.com', 'manolo.castejón@example.com', 'graciana.pinilla@example.com', 'vanesa.dávila@example.com', 'marcial.ramis@example.com', 'aarón.mateu@example.com', 'tito.montserrat@example.com', 'vasco.garcía@example.com', 'nadia.doménech@example.com', 'loreto.villalba@example.com', 'estefanía.naranjo@example.com', 'arturo.hierro@example.com', 'emiliana.beltran@example.com', 'rodrigo.urrutia@example.com', 'isidoro.echeverría@example.com', 'josefa.villaverde@example.com', 'cecilia.ibañez@example.com', 'victoria.salmerón@example.com', 'mar.taboada@example.com', 'maricruz.huertas@example.com', 'leonel.vázquez@example.com', 'jorge.llobet@example.com', 'nico.montenegro@example.com', 'cecilio.chacón@example.com', 'rodolfo.corominas@example.com', 'bernardo.ribera@example.com', 'candela.solano@example.com', 'maría luisa.aller@example.com', 'reyna.rius@example.com', 'leandro.ruano@example.com', 'roque.navarrete@example.com', 'nazaret.quiroga@example.com', 'priscila.solsona@example.com', 'esther.amores@example.com', 'dora.amores@example.com', 'tiburcio.cerdá@example.com', 'germán.ayllón@example.com', 'nicolás.pinilla@example.com', 'paz.robles@example.com', 'ceferino.sosa@example.com', 'calista.azorin@example.com', 'pancho.gomez@example.com ...

# %%
data_insert_reservas = []

for _, row in data.iterrows():
    id_reserva = row["id_reserva"]
    fecha_reserva = row["fecha_reserva"]
    inicio_estancia = row["inicio_estancia"]
    final_estancia = row["final_estancia"]
    precio_noche = row["precio_noche"]
    id_cliente = dictio_clientes.get(row["mail"])
    id_hotel = dictio_hoteles.get(row["nombre_hotel"])

    
    tupla_reserva = (id_reserva, fecha_reserva, inicio_estancia, final_estancia, precio_noche, id_cliente, id_hotel)

    if tupla_reserva not in data_insert_reservas:
        data_insert_reservas.append(tupla_reserva)

# %%
data_insert_reservas
# Out:
# [('40c4cb55-d1f5-407b-832f-4756b8ff77b4',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '1',
#   '1'),
#  ('f2ce8df5-7844-43e1-8c0f-97ce7a208f21',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '2',
#   '2'),
#  ('57d4515a-447d-4067-afcb-9bdcf4e4e915',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '3',
#   '3'),
#  ('ccbd9fe9-5a60-4f6f-bed3-73a7158ecba7',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '4',
#   '4'),
#  ('99c3dc4f-663c-45f7-849a-ac9313f3746a',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '5',
#   '5'),
#  ('a5da0906-0fe5-4c30-b193-863df67a7b84',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '6',
#   '6'),
#  ('3eca014e-f122-41d7-9dd3-b984b9153d57',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '7',
#   '7'),
#  ('8a68fb77-8798-4902-a92d-642ea5e47083',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '8',
#   '8'),
#  ('5e3de36b-3d2f-4cef-98d3-df826c56a4b1',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '9',
#   '9'),
#  ('2a39eb83-b3aa-4df0-93b3-1fdc0b0a9609',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '10',
#   '10'),
#  ('96a3727c-99fb-4ae0-a6c3-886504499ec2',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '11',
#   '11'),
#  ('18fa5887-c155-4064-ba8d-3b2948dd348b',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '12',
#   '3'),
#  ('9880f3ea-a29d-4acd-9fe1-96df1ffa46bd',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '13',
#   '12'),
#  ('22a3608a-1de2-40c7-8e2a-d22daf77390f',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '14',
#   '5'),
#  ('68b36da9-eeaa-4c31-91a8-d34fcc3956c8',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '15',
#   '13'),
#  ('b92dbe7c-4660-4e4c-9224-47cae0152bf9',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '16',
#   '11'),
#  ('9b16fc42-a7c6-4db9-98c7-30dbf2bb72b3',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '17',
#   '14'),
#  ('65fcc15f-f4c6-492a-b191-f180ae314bea',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '18',
#   '1'),
#  ('8a5b02f8-caa9-4917-a50d-a122c74a5c6d',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '19',
#   '15'),
#  ('24f9a853-2cef-4fb7-8182-d4f347c772d7',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '20',
#   '4'),
#  ('345b493b-5fcb-476c-940b-cce20444d64e',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '21',
#   '8'),
#  ('e9fc009e-6bbd-49a9-aaa1-499fbe5b7036',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '22',
#   '1'),
#  ('91569bdd-8430-4537-8245-6ca66e5c95ed',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '23',
#   '4'),
#  ('2713abaf-e02b-4e4b-9897-a6b9cd4862b5',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '24',
#   '16'),
#  ('56aa252f-8c76-4712-a8d8-cfa844b5711a',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '25',
#   '17'),
#  ('67cc0893-51de-461e-bdf3-72beb87d4672',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '26',
#   '13'),
#  ('728efa5a-8a5a-4e53-8b2b-349c4fcab5d9',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '27',
#   '12'),
#  ('f4b3e94a-2476-4923-953d-1f76ad90b520',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '28',
#   '18'),
#  ('166f113f-64cf-408d-b1c3-30ef155f8049',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '29',
#   '18'),
#  ('b4ec52c7-ac8d-4c68-93f2-56f80786978c',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '30',
#   '9'),
#  ('bec6c4c5-e6bf-4115-98d2-9c2f1161b77d',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '31',
#   '5'),
#  ('aca3e915-cf8f-4ee5-b921-f23f909f602b',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '32',
#   '10'),
#  ('47f91472-4a34-4e03-9cd2-64bbf695dcdd',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '33',
#   '6'),
#  ('4d0ca33e-6881-4eaa-8c32-caf6273e468b',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '34',
#   '9'),
#  ('f6149a73-99ec-46f9-ad92-c4174a564beb',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '35',
#   '11'),
#  ('25efcc1f-d69a-422f-a887-3341d57c6f09',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '36',
#   '5'),
#  ('5e53a3e0-ed87-48e8-9742-891fe94d1025',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '37',
#   '3'),
#  ('32aa8648-0f85-4405-86bd-ffe32c5bc3eb',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '38',
#   '16'),
#  ('b8fc310e-88a1-41eb-abf1-f772cf208fda',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '39',
#   '12'),
#  ('9202057b-976a-4e12-980e-d45cac1a2906',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '40',
#   '3'),
#  ('2af9827a-93df-4f5e-ac7d-bdda0c84ed31',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '41',
#   '9'),
#  ('a099af97-fd17-4374-86fe-9aae15f39bff',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '42',
#   '9'),
#  ('73b6396e-25dc-4516-9a8a-047fbdf14eb3',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '43',
#   '19'),
#  ('7d8a031b-affa-4506-8a21-36e2e298da06',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '44',
#   '8'),
#  ('4670b887-09ee-433b-afa1-556cbb1e930a',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '45',
#   '10'),
#  ('444992a6-ce95-43c1-bf32-b9ce3d754672',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '46',
#   '13'),
#  ('55d863f5-efd2-47ee-b047-b786c056ccef',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '47',
#   '7'),
#  ('458f6999-9db0-4430-88ad-b5d91cfd6ff4',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '48',
#   '4'),
#  ('9631e12c-9835-45fe-a21a-6271086c3452',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '49',
#   '10'),
#  ('ebd89c70-66d4-41d1-b218-dc9113ce6ce6',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '50',
#   '17'),
#  ('83b7096f-825e-4937-b0e2-4ec0391bc473',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '51',
#   '3'),
#  ('fc781901-7248-4af2-a828-9940d73e7cd9',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '52',
#   '3'),
#  ('dcffa24b-86dc-4814-9b26-e1264d8c3f03',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '53',
#   '17'),
#  ('16995b12-8790-4bb4-9e39-ad5eccbeb90d',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '54',
#   '17'),
#  ('1947713f-2d04-4f87-979d-47b803207fee',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '55',
#   '7'),
#  ('2e03c019-93d2-42ff-a9a4-9351952b3244',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '56',
#   '9'),
#  ('1706822e-7d2e-4287-a953-1f039ae68551',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '57',
#   '17'),
#  ('692a26ac-4f64-4e7d-aeb9-3c0ab9225d8d',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '58',
#   '13'),
#  ('509d1ab0-6acc-4c42-b352-4d8e86dfa96d',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '59',
#   '2'),
#  ('02fd1dcf-b5ef-4efc-9e02-0f7ba1d641b6',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '60',
#   '4'),
#  ('ca9bfa6c-1449-4239-9595-779c090af54b',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '61',
#   '7'),
#  ('5a5dd3f5-d360-4242-a827-2729e9d0fd61',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '62',
#   '13'),
#  ('b7055550-984b-48e4-83f6-637b7f4dd78c',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '63',
#   '8'),
#  ('013e4092-d233-4c2f-a772-9e66270e30a4',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '64',
#   '6'),
#  ('286afb47-7932-4250-987a-688b472b5344',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '65',
#   '11'),
#  ('d76d1cf2-0f78-4463-8fa8-51fe47c6c5ab',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '66',
#   '7'),
#  ('6de8b910-ab44-4a14-8369-f2723da145ed',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '67',
#   '14'),
#  ('f302dfc4-bdf4-40f0-b08c-6821d3044e5f',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '68',
#   '15'),
#  ('6741430e-762d-4548-9616-fc40362e0447',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '69',
#   '1'),
#  ('dd64cf88-9b1f-42ec-9340-39806f5bd744',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '70',
#   '10'),
#  ('d7978bb9-da0f-468c-977f-2062c1262a8c',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '71',
#   '3'),
#  ('49788f88-6522-4400-96c5-12757260aaeb',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '72',
#   '1'),
#  ('2cb6159f-ce6f-4c76-ad5c-fb471135b3b5',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '73',
#   '1'),
#  ('24bce2d2-a496-4d15-aa24-8796f173f0c7',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '74',
#   '13'),
#  ('fe3a68d9-f2ea-4af4-9512-5d890ed26aa2',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '75',
#   '3'),
#  ('05d40d78-a173-4044-9c72-ae9c2d8548d6',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '76',
#   '10'),
#  ('1696721f-a366-492c-8e7e-ce2bbd11e0b2',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '77',
#   '7'),
#  ('a5ad5040-06cf-47ca-9960-553a91600ce7',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '78',
#   '1'),
#  ('241e331b-007f-48d2-a184-7164c13d1cda',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '79',
#   '7'),
#  ('3fad3c2e-e8aa-437b-8c61-53c7e4b912b1',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '80',
#   '5'),
#  ('6a8b8b3d-bbde-4cb9-b9d4-68029065564c',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '81',
#   '17'),
#  ('9a69e4c1-f738-47a9-8d37-98c04675c506',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '82',
#   '18'),
#  ('2c74f8b9-05a8-4d01-95f7-63ce3ed5671f',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '83',
#   '6'),
#  ('77204866-fdb5-45b7-94db-51140a40b06e',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '84',
#   '3'),
#  ('5e9e808f-a53e-4255-9fc3-a4564be2063d',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '85',
#   '16'),
#  ('84902ee1-c371-4fb4-ad4e-bc8d6de33f45',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '86',
#   '15'),
#  ('904651ef-0e30-4880-ad20-6bb392a80aaa',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '87',
#   '5'),
#  ('92cdbb3d-7db3-4c60-b520-52107dc3cf18',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '88',
#   '3'),
#  ('1f822ddd-d04f-4cd4-8ac1-8c6c06583102',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '89',
#   '17'),
#  ('ce727457-b05d-4d48-b5e5-002a1a7274a8',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '90',
#   '11'),
#  ('be8685ea-5cc1-4983-bfe8-ccdf5170642e',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '91',
#   '2'),
#  ('1fd11394-7e1e-482b-8c16-8cb598f41e16',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '92',
#   '15'),
#  ('7078d68a-f0a9-4e31-bde8-25b5247a1f38',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '93',
#   '12'),
#  ('a0d92562-1485-4306-9dfb-a0078b2d0563',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '94',
#   '3'),
#  ('ce0aa969-ffa5-4e65-8eee-fcdeef2505f4',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '95',
#   '14'),
#  ('790cd2e1-ce99-4131-9c7d-73f3534dea93',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '96',
#   '8'),
#  ('18eff31c-cd63-4c05-a3f1-a0b05998018e',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '97',
#   '1'),
#  ('edfdc0ed-e580-4373-9317-f56cd55f8ef9',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '98',
#   '13'),
#  ('99d760d9-b9a0-4c9d-9e6d-d706238a743a',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '99',
#   '3'),
#  ('737db8d2-ef89-4a22-850f-5140b2cc1e9b',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '100',
#   '5'),
#  ('eeea3e90-5d2e-4388-a71c-23f539a47218',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '101',
#   '14'),
#  ('49f515de-4edd-4cbd-909a-7c4f53d16da6',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '102',
#   '6'),
#  ('3cc3f204-5347-4617-869f-cd1983b30c65',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '103',
#   '2'),
#  ('71d78fbd-4cbe-466f-b928-908ea21d416c',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '104',
#   '14'),
#  ('5fe3f4a7-18e8-4fbd-b6c8-d6f0299f5af1',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '105',
#   '7'),
#  ('5bc1f02e-486a-4c23-aba4-1a4291958e21',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '106',
#   '4'),
#  ('74e2b2c3-678d-49d5-9633-b5e0ef775ffb',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '107',
#   '2'),
#  ('f1252edf-cd6d-412d-9c99-47fdb83aeaaa',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '108',
#   '13'),
#  ('a2d8a845-32af-4c60-b3a9-e74366b70db0',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '109',
#   '11'),
#  ('93daea01-9f1a-4f34-b5e1-24ec1bd7b72b',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '110',
#   '10'),
#  ('de06e925-4221-416a-90d4-00bc635dd8c5',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '111',
#   '5'),
#  ('0d986817-dbeb-4beb-9fc1-777a1e9f7cb2',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '112',
#   '10'),
#  ('e98bca35-fc68-46ab-a04e-8df6db644e15',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '113',
#   '1'),
#  ('49dc985e-ca36-4692-9d8d-98b7bb5df716',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '114',
#   '1'),
#  ('337f0a62-b5b0-4b4d-bfe8-aa043ad39af1',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '115',
#   '7'),
#  ('86fbb1c4-9241-4b45-8bf5-3d59c79fe6da',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '116',
#   '18'),
#  ('d3500633-2caa-47b7-a6dd-796a37525dd2',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '117',
#   '14'),
#  ('2dd3d6b4-198f-468d-ac48-989847fec748',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '118',
#   '4'),
#  ('bd6deb8e-a500-4c0c-a706-24c1eec4fdce',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '119',
#   '13'),
#  ('a7764d9c-3169-4669-91cf-8e205be4f5d7',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '120',
#   '6'),
#  ('6455e672-2a92-49f3-9792-105c79f2bff1',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '121',
#   '16'),
#  ('f9ab1c28-737c-4b6a-9134-288f1d72bba7',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '122',
#   '7'),
#  ('56025d69-5792-4f68-801a-5ffc77bd7e7c',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '123',
#   '3'),
#  ('2b63564b-a163-4aa0-a3a2-d8d956eee050',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '124',
#   '17'),
#  ('f15ca9a2-2312-443a-9a78-ef7d1eee2b33',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '125',
#   '16'),
#  ('29ee49b5-269a-49ee-9502-09f1d17d6d95',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '126',
#   '15'),
#  ('37ef3cfc-c502-46dc-a51f-9391752151bd',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '127',
#   '5'),
#  ('88bcf602-5eed-41e7-88e2-622948f06801',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '128',
#   '10'),
#  ('8695bdae-bb21-4404-a9cb-1c7b8156e981',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '129',
#   '13'),
#  ('88b359a3-3ba5-4f55-adb3-eca51629e5d5',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '130',
#   '11'),
#  ('cce6889f-55ea-4287-9058-26e77b538234',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '131',
#   '9'),
#  ('f2945ede-3cbe-4da5-9783-bce3017dae6b',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '132',
#   '7'),
#  ('fbaeb2d5-f1a9-4e56-a9a6-40e0ab6c9e70',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '133',
#   '8'),
#  ('25d87ec2-9485-4646-91ec-be1ae16a4988',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '134',
#   '16'),
#  ('d3f37083-97d4-474d-9cae-d47055526b43',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '135',
#   '11'),
#  ('3e60606c-faec-4627-82a9-21ad892a6015',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '136',
#   '10'),
#  ('6911c54e-a723-4735-8791-44630316d2c5',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '137',
#   '17'),
#  ('29c26528-c4c1-4c29-bb96-049330ed13aa',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '138',
#   '4'),
#  ('8f2d6bfa-0157-4687-a63d-a4bc74f4ae7d',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '139',
#   '11'),
#  ('0794ad33-6123-4fbe-9fe4-0acd50ebe4d4',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '140',
#   '15'),
#  ('9abb88d1-69f0-41ef-88bc-070704a6d471',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '141',
#   '9'),
#  ('ab40347c-8abe-4b4f-8efa-4cbd684dfb1e',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '142',
#   '10'),
#  ('050c86cd-1a86-493a-ac9f-306abcc7ac80',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '143',
#   '8'),
#  ('e69f8fe7-5873-4460-b008-5c02a222cc7e',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '144',
#   '8'),
#  ('b695cb1b-7a70-4595-9479-1894b4621f4b',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '145',
#   '13'),
#  ('d7a7ed1d-2cdf-4696-a6d6-9b61720c891c',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '146',
#   '1'),
#  ('ee28c232-4cb7-43e1-b93c-ac125b352da3',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '147',
#   '12'),
#  ('512e5100-4f5c-437e-a4e1-0132bf3ef313',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '148',
#   '1'),
#  ('1a14f609-6c60-40f6-b65e-2cccbe87cd59',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '149',
#   '14'),
#  ('7242c18a-8f29-4faf-935c-2199bb208383',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '150',
#   '2'),
#  ('cb4f4365-e47f-4adc-a495-930ed518950e',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '151',
#   '3'),
#  ('0349d4e0-b2a9-4ce2-b2c2-46fe17e34e2f',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '152',
#   '16'),
#  ('c43fcb7b-efb8-4072-9a74-dbdf96485be9',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '153',
#   '4'),
#  ('c426ec52-6aa1-494f-9e4a-2fd06cdf0606',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '154',
#   '6'),
#  ('94fcd56b-3b25-4459-8258-b4191be8b2aa',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '155',
#   '4'),
#  ('ecbd3465-ae02-4b96-85f6-86f70f7989f5',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '156',
#   '16'),
#  ('e1ff0029-572a-485b-b71b-272966ccae60',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '157',
#   '19'),
#  ('77a9c44e-4e06-4cb1-b367-b25569d8944f',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '158',
#   '13'),
#  ('6cd11384-b968-4932-b228-a2e0d427cd81',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '159',
#   '14'),
#  ('38429c38-5e93-4757-9490-cfd1d639cce0',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '160',
#   '16'),
#  ('199e45fd-88a0-4490-bff1-5e1534b20014',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '161',
#   '7'),
#  ('d6b6fcf5-d634-4034-aaef-dc88172f0d25',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '162',
#   '13'),
#  ('f020e6c3-c2e7-4232-a4b2-0c90cbcab83b',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '163',
#   '12'),
#  ('aa974bd2-8af3-420d-921a-ad4d5a293fd9',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '164',
#   '9'),
#  ('0a4881d8-84df-4fff-920c-3d0e19eb1594',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '165',
#   '6'),
#  ('68b17fa0-f2a8-44b5-aa1f-ab853db39ff1',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '166',
#   '17'),
#  ('9cea0b32-d568-4256-a3ec-fe7df62de4f9',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '167',
#   '15'),
#  ('1cf9406d-4c66-4367-997f-34de4f0139e8',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '168',
#   '1'),
#  ('dff5b144-874d-4a31-be70-4b0d3e7a6fcc',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '169',
#   '16'),
#  ('93cfb819-1b4f-462b-9bc8-9d58fae4b13e',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '170',
#   '4'),
#  ('dfc4b88f-677f-4d41-a04b-72982c3d5db9',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '171',
#   '6'),
#  ('9daa565e-1922-4c9d-af34-5034c986f7d1',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '172',
#   '9'),
#  ('33acadd9-0a41-4978-b049-303fd8899ae2',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '173',
#   '13'),
#  ('b70dd0f4-57d2-47ac-9cbc-6070621737b6',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '174',
#   '8'),
#  ('0ceb9cdf-8db6-4d0e-b04e-dd497f351364',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '175',
#   '17'),
#  ('7c2539df-f6f9-47a5-8ab6-f4dd1aff4a9d',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '176',
#   '14'),
#  ('45f60da0-6c89-46ad-82a0-23b57b36d6d8',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '177',
#   '2'),
#  ('0ca72508-704d-4f0d-9308-70d716d80ff2',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '178',
#   '11'),
#  ('310649b1-5bf7-40ce-8924-d3a50488d15e',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '179',
#   '6'),
#  ('8b7ab7d8-b34a-4bfd-8ef2-d1828a3d750c',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '180',
#   '4'),
#  ('14f6bf80-db2c-4a06-85c5-0935725ba6ef',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '181',
#   '9'),
#  ('01a5e667-900f-4ccf-a495-0281ce658c5b',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '182',
#   '18'),
#  ('5923c68b-040d-41e3-b37a-f9d9cb60fee1',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '183',
#   '15'),
#  ('d25466f5-83c2-4d20-abb9-20929650f418',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '184',
#   '11'),
#  ('1a323125-f15c-4e7f-a0bb-a5e278f8ede8',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '185',
#   '13'),
#  ('8bb4011e-ec87-451f-9c92-9b2804b3fb7c',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '186',
#   '15'),
#  ('2086fa68-5cd5-4ae3-925a-836397355dcf',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '187',
#   '5'),
#  ('0d431c17-f9f3-45bf-894d-ad6810668bce',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '188',
#   '12'),
#  ('8fa33c28-1da0-4117-9b4a-0135e7056157',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '189',
#   '11'),
#  ('35661d72-f2f4-4e68-ab5e-72f51beae800',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '190',
#   '2'),
#  ('e8a391c9-22d8-4c17-bda9-7b4985e3e12b',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '191',
#   '3'),
#  ('538a5362-5221-4755-9d96-4a049591e7a4',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '192',
#   '11'),
#  ('f3d24aa6-a71f-4160-b4ef-3fead219605a',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '193',
#   '9'),
#  ('2a9f7531-4102-410e-a284-4046e07f917a',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '194',
#   '3'),
#  ('2837fe63-e0fe-4c78-8f5b-bea2301ebc3d',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '195',
#   '3'),
#  ('450e845f-1362-4e99-b7d2-2b34c509b412',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '196',
#   '16'),
#  ('2ec18dfa-95ef-4628-8321-ff3417d699ed',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '197',
#   '2'),
#  ('62631cc9-1a57-458d-bbb8-b295088de4b5',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '198',
#   '6'),
#  ('d078f387-4fca-40d7-b775-36b08e2d5d08',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '199',
#   '6'),
#  ('37a24fa6-c0ae-413c-8e53-eda4bd7e701f',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '200',
#   '14'),
#  ('3c81c427-1324-453f-b978-1ecb92f54485',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '201',
#   '10'),
#  ('a9f4619a-118e-4bed-b8a7-f162b98d9b7e',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '202',
#   '18'),
#  ('c1d79127-0d8e-4e2f-9baa-fa7d9e04411a',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '203',
#   '17'),
#  ('148eb9c7-7e6e-4c42-a09f-2e386ccfcbfb',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '204',
#   '18'),
#  ('c98443c4-8f6d-428a-9354-42a0bcef7f9c',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '205',
#   '17'),
#  ('b9295a4d-c7f7-4248-843b-becc12d46885',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '206',
#   '19'),
#  ('760b9113-56ad-4c5f-bb47-74980488d028',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '207',
#   '9'),
#  ('87104b37-4393-437e-ba6e-04e59159487e',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '208',
#   '12'),
#  ('ddefde3e-de0c-4e10-858e-bdc4fe3fd546',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '209',
#   '11'),
#  ('26c20a07-9044-4357-a3fa-8d012f0a37b6',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '210',
#   '5'),
#  ('d54038af-0bec-4a02-a652-848f419d834b',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '211',
#   '13'),
#  ('564c8097-e3ca-44c1-812e-4c980c7a0ac2',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '212',
#   '3'),
#  ('20e8eade-35d0-4714-9c39-8599478a27d6',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '213',
#   '12'),
#  ('3c267f65-351d-4dab-bc2c-8e2b9950ff5a',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '214',
#   '15'),
#  ('8e25f072-fec8-4722-985d-9b0d2f8ac0d7',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '215',
#   '5'),
#  ('b3d1f8ae-a3b4-4c96-b748-d86d8e7519f4',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '216',
#   '3'),
#  ('739b3fe5-f33e-4260-87e7-eb5b160692ab',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '217',
#   '13'),
#  ('d858d574-b65e-4f16-926a-8fbe27e078e3',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '218',
#   '7'),
#  ('8948495c-4177-43d5-96a2-27eaff24e51d',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '219',
#   '2'),
#  ('b930b971-9161-4976-92cb-35699439ad11',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '220',
#   '3'),
#  ('0129fef0-c8f8-4dfa-85b6-c376c194bf7e',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '221',
#   '4'),
#  ('c5cf3357-cedf-4a53-89f8-c0f5341031f7',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '222',
#   '10'),
#  ('f2a17eb6-af79-4191-bdbd-72039df177fb',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '223',
#   '19'),
#  ('38298655-48b7-4876-83d5-3fc5adcaed2c',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '224',
#   '2'),
#  ('ef510fde-f6b6-4d27-9bed-9f19eebff851',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '225',
#   '9'),
#  ('7a37b927-aaa5-458d-98ef-67b4104d2c82',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '226',
#   '19'),
#  ('13a6b79b-272a-4373-bf09-642d9ecb1a7d',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '227',
#   '10'),
#  ('efc2ef63-1431-444a-9ddd-f92c33e0ab16',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '228',
#   '12'),
#  ('f61c1e29-7451-447f-89a2-7987703072bd',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '229',
#   '7'),
#  ('dfdf6187-8365-482a-9624-7b5ceb0cbc05',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '230',
#   '14'),
#  ('9409dca1-00a4-4112-b82d-a5ec8e5e6dce',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '231',
#   '3'),
#  ('af53315b-a47b-4828-8c13-31bb64100807',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '232',
#   '9'),
#  ('e14473e8-a6f1-4f8a-87c4-fc5fba64fefb',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '233',
#   '10'),
#  ('71b55659-4100-48bc-9112-3e186756e8a2',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '234',
#   '14'),
#  ('44a113be-8ef5-41ee-8865-0afea0b691da',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '235',
#   '6'),
#  ('985d56b5-be16-434d-8010-6a9dd9531a5f',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '236',
#   '12'),
#  ('887eddd5-450c-4dda-9b2f-2b3c9cfea61f',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '237',
#   '8'),
#  ('c9db2554-cbc8-43b9-addb-9d55104c59af',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '238',
#   '7'),
#  ('814b48ed-a853-4d9a-a47b-f6c3cd571149',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '239',
#   '17'),
#  ('f2a064ac-1762-4edd-a642-cd4959a25cac',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '240',
#   '16'),
#  ('370ee18c-0418-45e1-bb3b-21744ec7980f',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '241',
#   '1'),
#  ('e5d9916d-d181-412a-bb4c-d4d9096dc14d',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '242',
#   '4'),
#  ('7aba736d-f7ae-444c-8bea-19e88840dbec',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '243',
#   '4'),
#  ('7d468a35-57a3-4e89-a270-3cb1eee9b139',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '244',
#   '4'),
#  ('df7851b1-6357-476f-99cb-30d84c1a4870',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '245',
#   '9'),
#  ('c860c408-9c29-48c2-8614-417d4e3a5950',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '246',
#   '1'),
#  ('22036c1f-219c-4269-9800-c134883066bc',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '247',
#   '11'),
#  ('1185da8a-7773-463c-84a6-9f4b650e91e4',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '248',
#   '11'),
#  ('0550175a-eb5e-4b8f-be0f-9c666740e92d',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '249',
#   '4'),
#  ('8b63ceb7-d840-48c3-9c97-6d4ea4a1c2e8',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '250',
#   '9'),
#  ('909430e8-932a-4e6f-9746-1b7f6e42b9a6',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '251',
#   '12'),
#  ('fdd9800c-fd6f-4900-9f8e-c1fa915f518e',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '252',
#   '17'),
#  ('5f33cc65-0b69-4c5e-8307-1d6548c3fe6d',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '253',
#   '5'),
#  ('7454eb30-705f-4654-8886-c1fb6ba75956',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '254',
#   '13'),
#  ('36a391fd-e55d-4f42-af6d-0bc8f4610157',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
# ...
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '916',
#   '10'),
#  ('ad3aa44f-423a-4754-a590-a705217e3e38',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '917',
#   '12'),
#  ('f8075269-f63e-4144-846c-7b8fb2ac835b',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '918',
#   '18'),
#  ('504e3ce3-10e1-4349-a994-2a2ca1a4728b',
#   Timestamp('2025-02-11 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '919',
#   '1'),
#  ('bbdafdb5-3b39-4187-95f4-18550632514a',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '920',
#   '12'),
#  ('6231172a-b1ae-4d52-b932-d479ee8db56f',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '921',
#   '7'),
#  ('219bfb4b-a323-43f5-aeb7-70e1167d11c1',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '922',
#   '19'),
#  ('a1258bd0-380c-4ddc-952a-68f49db8e47a',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '923',
#   '1'),
#  ('a9556156-78c2-42fb-8a57-596de0c91018',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '924',
#   '1'),
#  ('e8744831-0d1f-4f39-8b33-cd59e2ec8528',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '925',
#   '8'),
#  ('eff026d8-d843-4193-9c62-8c539e1232a4',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '926',
#   '18'),
#  ('ce777b60-241b-4c1e-a7e3-9eec1802f7bd',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '927',
#   '5'),
#  ('6a1e4578-f55d-4e1e-85cd-d9d7af0c8400',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '928',
#   '17'),
#  ('6082511b-a1ea-4f53-b0fc-4b1d3e0a1726',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '929',
#   '14'),
#  ('dfad0a3a-54dc-418e-9390-ba2112efb983',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '930',
#   '3'),
#  ('4f5dc072-afc7-45f0-aade-e9cc5a5b3318',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '931',
#   '17'),
#  ('09678f06-8cce-439c-8e8f-24c483e8a562',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '932',
#   '9'),
#  ('aefb9f1c-b5e9-4224-a452-9c6b18ff3e40',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '933',
#   '14'),
#  ('01b6454d-928b-432a-ad0d-d9e545834c08',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '934',
#   '2'),
#  ('2439980e-62d3-4d9a-9d6d-0e9d0a4ac9d1',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '935',
#   '12'),
#  ('e14ae48f-1eba-4472-8eae-3597bf3f7cff',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '936',
#   '16'),
#  ('1716757d-10a0-418b-8476-a3bf39c23440',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '937',
#   '11'),
#  ('6da87f0c-ed89-46f8-925c-93f913f281b5',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '938',
#   '19'),
#  ('2dbc5e37-416e-4e5c-a6dc-d638dbeb4ceb',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '939',
#   '14'),
#  ('d05aa5c5-a603-4194-bf46-ef97dac3693a',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '940',
#   '18'),
#  ('c9a76539-bc4b-4e09-9211-a8c05a2b6505',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '941',
#   '12'),
#  ('96c92939-c5a9-4e22-ba4f-294ddee9a4f2',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '942',
#   '1'),
#  ('0b104e0f-3f39-4a9b-baab-e0c975943a77',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '943',
#   '19'),
#  ('0a451ecb-cf96-4bdd-ab9d-ab06e7beef55',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '944',
#   '13'),
#  ('95e37157-e2b0-49bc-bc64-e437b208249a',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '945',
#   '17'),
#  ('27937973-90d8-492c-9ae1-1d18d0fa60ec',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '946',
#   '7'),
#  ('7b4ba34b-27b9-45a0-90a9-ad3322c9cfcf',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '947',
#   '17'),
#  ('0761f50a-642e-492a-ac2f-1e2fd88386af',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '948',
#   '3'),
#  ('9b88fa33-3af3-407a-979d-3d94efa83070',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.7629755178908,
#   '949',
#   '13'),
#  ('42618786-b655-4166-8b79-6483bf0a64e1',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '950',
#   '15'),
#  ('562d19a1-0d32-4ce4-b000-57a50680b177',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '951',
#   '18'),
#  ('53a2caee-6e40-4a75-a51a-f80f361380ae',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '952',
#   '16'),
#  ('0869b6a4-3ee3-45fc-8335-8581c84bf840',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '953',
#   '17'),
#  ('841f12b5-cced-40dc-b925-8aa069d21586',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '954',
#   '14'),
#  ('2e9558d9-aa1c-4778-8e55-da01f081a9c6',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '955',
#   '7'),
#  ('cf0e17f7-197f-4c27-baaf-5e44713bcd72',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '956',
#   '16'),
#  ('83a9686e-1e15-4cf1-9092-7c31e39db089',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '957',
#   '12'),
#  ('77d92085-7f04-4605-873d-4e84f53c9a81',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '958',
#   '9'),
#  ('e0151060-545e-42be-bd38-e00e990780f0',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '959',
#   '9'),
#  ('2a8638ed-bc39-4a8f-929a-63dedddb84ac',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '960',
#   '9'),
#  ('f3f60f9c-34f9-439e-884f-e63e1c64da0e',
#   Timestamp('2025-02-01 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '961',
#   '11'),
#  ('5a60cdbc-046e-4fa0-81bf-0ead4f63e013',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '962',
#   '4'),
#  ('65fc5868-228a-44cb-98da-27d083f77da2',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.2415151515151,
#   '963',
#   '11'),
#  ('3e1b64b0-f557-4f58-bd25-6d7d197a6871',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '964',
#   '10'),
#  ('cfd15395-3c49-4aff-a2af-6b2d6e538814',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '965',
#   '14'),
#  ('d8e17962-cf1a-4cb1-a634-cc7b177d60a2',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '966',
#   '5'),
#  ('2c8e8b47-ca9a-49aa-9b69-5a2221334229',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '967',
#   '2'),
#  ('ccf43048-7a96-40d3-ae92-d523387874b4',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '968',
#   '19'),
#  ('3b92dc5f-ac98-4860-8bf6-993a82edf527',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '969',
#   '9'),
#  ('2c1cdb2a-55e3-445d-8b8c-7cba108b605e',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   279.802141453831,
#   '970',
#   '17'),
#  ('7c6c23c8-dc79-420d-818c-305c7ceeefcb',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   264.96716504854373,
#   '971',
#   '9'),
#  ('58ac840a-9e5f-4e6e-9d4c-517760aa541a',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '972',
#   '8'),
#  ('921364e4-b0f3-4512-9385-8a4ff31307fe',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   273.2852741020794,
#   '973',
#   '15'),
#  ('8c57cfc9-5b6e-4ae2-8644-b4b6ecb6799a',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '974',
#   '16'),
#  ('adfcd19f-9db0-4f9f-b1c5-fe7fd49f233a',
#   Timestamp('2025-02-07 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '975',
#   '14'),
#  ('467c7543-00b9-431e-9b03-501df8c1d151',
#   Timestamp('2025-02-05 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '976',
#   '3'),
#  ('bb989ed2-08d4-4558-aa36-faa8bb9be5d6',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '977',
#   '2'),
#  ('85912e84-a930-4bde-a5e6-1130a4da6ce5',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   280.1512428298279,
#   '978',
#   '4'),
#  ('751c81f4-2232-40b4-bdee-ff1cf7c16a9c',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '979',
#   '8'),
#  ('ccd6d109-fcb0-4fd7-9131-33738e15073f',
#   Timestamp('2025-02-10 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   275.2259210526316,
#   '980',
#   '2'),
#  ('406af5ff-88fc-4762-90ee-781530322825',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '981',
#   '12'),
#  ('219e5ab0-4c41-4abf-85a9-dd1e2b0a0e27',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   282.4921499013806,
#   '982',
#   '6'),
#  ('97737249-ef23-4b23-9f23-00a43fc8393f',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.4023353293413,
#   '983',
#   '7'),
#  ('5d6d1a35-6130-4d31-a75b-6df2b3af838a',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.4021186440678,
#   '984',
#   '19'),
#  ('cb344854-97cb-40d3-b010-131d93e796c4',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '985',
#   '1'),
#  ('191cfc02-161f-45ce-b144-7d41255ba9c7',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '986',
#   '16'),
#  ('8e5f04c6-e6c6-4ebd-a1a2-5a556a8a596f',
#   Timestamp('2025-02-03 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   271.7063529411765,
#   '987',
#   '8'),
#  ('a3aaf673-52a3-4faf-8086-45262e01a10f',
#   Timestamp('2025-02-02 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '988',
#   '14'),
#  ('fd07f23d-b56d-4e39-a3e8-f7c15a69c7f4',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '989',
#   '1'),
#  ('93da7706-5e58-4387-a877-9f4b24fb8e7c',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   278.2439960629921,
#   '990',
#   '5'),
#  ('0db1feee-b093-4eed-a8f9-f3eecb280b65',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '991',
#   '14'),
#  ('2f779d98-a4a6-4d02-aa79-2d8258cdb3ae',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   272.7331755424063,
#   '992',
#   '10'),
#  ('2751f29a-7d83-45a9-b771-c12bfeb2689a',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   277.31882352941176,
#   '993',
#   '16'),
#  ('49d141e2-ab1c-4d3f-8e31-7e36a2e5ba2d',
#   Timestamp('2025-02-12 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.99844357976656,
#   '994',
#   '3'),
#  ('10aa8159-0eb6-43bd-94c2-27bbb24b79f6',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '995',
#   '1'),
#  ('c7020f6d-0bf6-4fc4-ae26-93829acd0a6b',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '996',
#   '1'),
#  ('ecbc5754-d154-4083-ab9e-08026ba5a954',
#   Timestamp('2025-02-06 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   267.93135869565214,
#   '997',
#   '14'),
#  ('c795a03f-553c-4f15-9cf0-00a7beb82154',
#   Timestamp('2025-02-08 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   269.9356074766355,
#   '998',
#   '12'),
#  ('fe1f24b6-84cb-48a5-b6be-72c010dfcaa3',
#   Timestamp('2025-02-04 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   276.61238095238093,
#   '999',
#   '1'),
#  ('00daa6d1-e172-410f-b998-35a2b447f37f',
#   Timestamp('2025-02-09 00:00:00'),
#   Timestamp('2025-03-01 00:00:00'),
#   Timestamp('2025-03-02 00:00:00'),
#   284.2829629629629,
#   '1000',
#   '18'),
#  ...]

# %%
# Creamos la query de inserción de los datos de ciudad
insert_query_reservas = """ 
                        INSERT INTO reservas (id_reserva, fecha_reserva, inicio_estancia, final_estancia, precio_noche, id_cliente, id_hotel)
                        VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

# %%
# Ejecutamos la query y le indicamos los valores 
cur.executemany(insert_query_reservas, data_insert_reservas)
conn.commit()

# %%
# vamos a comprobar que se ha creado correctamente
query_reservas = """
    SELECT * 
    FROM reservas; 
"""
cur.execute(query_reservas)
cur.fetchmany(3)
# Out:
# [('40c4cb55-d1f5-407b-832f-4756b8ff77b4',
#   datetime.date(2025, 2, 9),
#   datetime.date(2025, 3, 1),
#   datetime.date(2025, 3, 2),
#   276.61238095238093,
#   '1',
#   '1'),
#  ('f2ce8df5-7844-43e1-8c0f-97ce7a208f21',
#   datetime.date(2025, 2, 8),
#   datetime.date(2025, 3, 1),
#   datetime.date(2025, 3, 2),
#   275.2259210526316,
#   '2',
#   '2'),
#  ('57d4515a-447d-4067-afcb-9bdcf4e4e915',
#   datetime.date(2025, 2, 2),
#   datetime.date(2025, 3, 1),
#   datetime.date(2025, 3, 2),
#   269.99844357976656,
#   '3',
#   '3')]

# %% [markdown]
# ## Cierre de la conexión

# %%
# una vez hemos terminado de trabajar es necesario cerrar la conexión y el cursor.
cur.close()
conn.close()

# %% [markdown]
# ## Funciones de carga

# %%
# funcion para crear la conexion con la base
def conexion_BBDD(nombre_BBDD = "BBDD_Hoteles", usuario = "postgres", contraseña = "admin", anfitrion = "localhost", puerto = "5432"):
    conn = ps.connect(
        dbname = nombre_BBDD, # base a la que nos queremos conectar
        user = usuario,
        password = contraseña,
        host = anfitrion,
        port = puerto)
    
    cur = conn.cursor()
    cur.execute("SELECT version();")
    return cur.fetchone()

# %%
# Carga tabla ciudad
def carga_tabla_ciudad(ciudad = "Madrid"):
    data_to_insert = [ciudad]
    insert_query = """ 
                        INSERT INTO ciudad (nombre_ciudad)
                        VALUES (%s) 
                    """
    cur.execute(insert_query, data_to_insert)
    conn.commit()
    query = """
                    SELECT * 
                    FROM ciudad; 
                """
    cur.execute(query)
    return cur.fetchall()

# %%
# Carga tabla eventos
# la query será tal que así: "SELECT nombre_ciudad, id_ciudad FROM ciudad"
def carga_tabla_eventos(dataframe, query_ciudad):
    cur.execute(query_ciudad)
    dictio = dict(cur.fetchall())

    data_to_insert = []


    for i, row in dataframe.iterrows():
        nombre_evento = row["nombre_evento"]
        url_evento = row["url_evento"]
        codigo_postal = row["codigo_postal"] if row["codigo_postal"] != 0 else None # en este caso los valores que son igual a 0 se corresponden con valores nulos, por lo que le indicamos que si el valor es igual a 0 nos ponga un nulo
        direccion = row["direccion"] if pd.notna(row["direccion"]) else None # tenemos valores nulos en esta columna, de manera que le indicamos, que si el elemento no es nulo nos lo coja, y si es nulo, nos incluya un None, ya que sql no acepta valores nulos que no sean None
        horario = row["horario"] if pd.notna(row["horario"]) else None
        fecha_inicio = row["fecha_inicio"]
        fecha_fin = row["fecha_fin"]
        organizacion = row["organizacion"] if pd.notna(row["organizacion"]) else None
        id_ciudad = dictio.get("Madrid")

        data_to_insert.append((nombre_evento, url_evento, codigo_postal, direccion, horario, fecha_inicio, fecha_fin, organizacion, id_ciudad))
        
    insert_query = """ 
                    INSERT INTO eventos (nombre_evento, url_evento, codigo_postal, direccion, horario,
                    fecha_inicio, fecha_fin,organizacion, id_ciudad)
                    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
                    """
    cur.executemany(insert_query, data_to_insert)
    conn.commit()

    query = """
                    SELECT * 
                    FROM eventos; 
                """
    cur.execute(query)
    return cur.fetchmany(3)

# %%
# Carga tabla hoteles
# la query será tal que así: "SELECT nombre_ciudad, id_ciudad FROM ciudad"
def carga_tabla_hoteles(dataframe, query_ciudad):
    data_to_insert = []

    cur.execute(query_ciudad)
    dictio = dict(cur.fetchall())

    for _, row in dataframe.iterrows():
        id_hotel = row["id_hotel"]
        nombre_hotel = row["nombre_hotel"] 
        competencia = row["competencia"] 
        valoracion = row["estrellas"] 
        id_ciudad = dictio.get("Madrid") 

        tupla = (id_hotel, nombre_hotel, competencia, valoracion, id_ciudad)

        if tupla not in data_to_insert:
            data_to_insert.append(tupla)
    
    insert_query = """ 
                        INSERT INTO hoteles (id_hotel, nombre_hotel, competencia, valoracion, id_ciudad)
                        VALUES (%s, %s, %s, %s, %s)
            """
    cur.executemany(insert_query, data_to_insert)
    conn.commit()

    query = """
    SELECT * 
    FROM hoteles; 
        """
    cur.execute(query)
    return cur.fetchmany(3)

# %%
# Carga tabla clientes
def carga_tabla_clientes(dataframe):
    data_to_insert = []

    for _, row in dataframe.iterrows():

        id_cliente = row["id_cliente"]
        nombre = row["nombre"],
        apellido = row["apellido"],
        mail = row["mail"]

        tupla = (id_cliente, nombre, apellido, mail)

        if tupla_cliente not in data_to_insert:
            data_to_insert.append(tupla)
    
    insert_query = """ 
                        INSERT INTO clientes (id_cliente, nombre, apellido, mail)
                        VALUES (%s, %s, %s, %s)
                        """
    cur.executemany(insert_query, data_to_insert)
    conn.commit()

    query = """
                    SELECT * 
                    FROM clientes; 
                """
    cur.execute(query)
    return cur.fetchmany(3)

# %%
# Carga tabla reservas
# La query de clientes será así: "SELECT nombre, id_cliente FROM clientes"
# la query de hoteles será así: "SELECT nombre_hotel, id_hotel FROM hoteles"
def carga_tabla_reservas(dataframe, query_clientes, query_hoteles):
    
    cur.execute(query_clientes)
    dictio_clientes = dict(cur.fetchall())

    cur.execute(query_hoteles)
    dictio_hoteles = dict(cur.fetchall())

    data_to_insert = []

    for _, row in dataframe.iterrows():
        id_reserva = row["id_reserva"]
        fecha_reserva = row["fecha_reserva"]
        inicio_estancia = row["inicio_estancia"]
        final_estancia = row["final_estancia"]
        precio_noche = row["precio_noche"]
        id_cliente = dictio_clientes.get(row["nombre"])
        id_hotel = dictio_hoteles.get(row["nombre_hotel"])

        data_to_insert.append((id_reserva, fecha_reserva, inicio_estancia, final_estancia, precio_noche, id_cliente, id_hotel))
    
    insert_query = """ 
                        INSERT INTO reservas (id_reserva, fecha_reserva, inicio_estancia, final_estancia, precio_noche, id_cliente, id_hotel)
                        VALUES (%s, %s, %s, %s, %s, %s, %s)
                        """
    
    cur.executemany(insert_query, data_to_insert)
    conn.commit()

    query = """
                    SELECT * 
                    FROM reservas; 
                    """
    cur.execute(query)
    cur.fetchmany(3)
